# %% [markdown]
# # Flip Robo Technologies
#
# ## Webscraping Assignment 3
#
# ### Submitted by : Shahla M

# %%
#import necessary librabies for webscraping with selenium

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests
from time import sleep

# %% [markdown]
# Q1: Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#open the page in automated chrome browser

driver.get("https://www.amazon.in/")
time.sleep(2)

# %%
# Taking input from user

user_input=input('Enter the Product you which you want to search :')
# Out:
# Enter the Product you which you want to search :guitar

# %%
# Finding search

search=driver.find_element(By.XPATH,'//input[@id="twotabsearchtextbox"]')

# clearing any previous input in search bar

search.clear()

# %%
# Puting input to search button and click on seach

search.send_keys(user_input)

button=driver.find_element(By.XPATH,'//input[@id="nav-search-submit-button"]')
button.click()

# %% [markdown]
# Q2: In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# Make Empty list to save the scrapped data

brand_name =[]
product = []
price =[]
exchange =[]
excepted_delivery =[]
availability =[]
url =[]

# %%
#First scrape URL of the searched product for first 3 pages

start= 0
end= 3
for page in range(start, end):
    url_tags =driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url_tags:
        url.append(i.get_attribute('href'))
    time.sleep(2)
    
    # locating next page button and clicking
    
    next_page = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_page.click()
    time.sleep(6)

# %%
len(url)
# Out:
# 182

# %%
for i in url:
    driver.get(i)
    time.sleep(3)
    
    # Extracting Brand Name
    try:
        brand_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[4]/div[4]/div[43]/div/table/tbody/tr[1]/td[2]/span')
        brand_name.append(brand_tags.text) 
        
    except NoSuchElementException:
        brand_name.append('-')
    time.sleep(2)
    
    # Extracting product name
    try:
        product_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[4]/div[4]/div[1]/div/h1/span')
        product.append(product_tags.text)
        
    except NoSuchElementException:
        product.append('-')
    time.sleep(2)
    
    # Extracting Price
    try:
        price_tags =driver.find_element(By.XPATH,'//span[@class="a-price a-text-price a-size-medium apexPriceToPay"]')
        price.append(price_tags.text)
        
    except NoSuchElementException:
        price.append('-')
    time.sleep(2)
    
    # Extracting Return or exchange details
    try:
        ex_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[4]/div[4]/div[22]/div[2]/div/div/div/div[2]/span/div[2]/a')
        exchange.append(ex_tags.text)
        
    except NoSuchElementException:
        exchange.append('-')
    time.sleep(2)
    
    # Extracting Expected Delivery via Xpath
    try:
        delivery_tags =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[4]/div[1]/div[3]/div/div/div/div/form/div/div/div/div/div[3]/div/div[2]/div[8]/div[1]/div/div/div[2]/span/span[1]')
        excepted_delivery.append(delivery_tags.text)
        
    except NoSuchElementException:
        excepted_delivery.append('-')
    time.sleep(2)
    
    # Extracting availability via Xpath
    try:
        availability_tags =driver.find_element(By.XPATH,'//span[@class="a-size-medium a-color-success"]')
        availability.append(availability_tags.text)
        
    except NoSuchElementException:
        availability.append('-')
    time.sleep(2)

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(brand_name,product,price, exchange,excepted_delivery,availability, url))

data= pd.DataFrame(data_list, 
    columns =['Brand_Name', 'Product', 'Price', 'Return/Exchange','Excepted Delivery','Availability','URL'],
    index=pd.RangeIndex(start=1, stop=183, name='Sr. No.'))

#Print the required data

print ("Details of each product listed in first 3 pages from amazon.com:\n")
data
# Out:
# Details of each product listed in first 3 pages from amazon.com:
#         Brand_Name                                            Product Price  \
# Sr. No.
# 1                -  Kadence Slowhand Premium Jumbo Semi Acoustic G...     -
# 2                -  Hontral S4 String Decor Guitar Children's Musi...     -
# 3                -  Blueberry B-D38, 38" Acoustic Guitar Kit Inbui...     -
# 4                -  Festra 38C, 38 Inch Acoustic Guitar Kit with B...     -
# 5                -                                                  -     -
# ...            ...                                                ...   ...
# 178              -                                                  -     -
# 179              -  Mustang Music Combo Of Guitar Tuner And A Fram...     -
# 180              -                                                  -     -
# 181              -  SG Musical - Silver - - Capo For Acoustic Guit...     -
# 182              -  SG Musical - Store - Capo, Quick Change Capo F...     -
#
#         Return/Exchange        Excepted Delivery Availability  \
# Sr. No.
# 1                     -                        -
# 2                     -    Wednesday, 2 November    In stock.
# 3                     -  October 30 - November 3    In stock.
# 4                     -     Thursday, 3 November    In stock.
# 5                     -                        -    In stock.
# ...                 ...                      ...          ...
# 178                   -                        -    In stock.
# 179                   -       Friday, 4 November    In stock.
# 180                   -                        -    In stock.
# 181                   -     Saturday, 5 November    In stock.
# 182                   -     Saturday, 5 November    In stock.
#
#                                                        URL
# Sr. No.
# 1        https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2        https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 3        https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 4        https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 5        https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ...                                                    ...
# 178      https://www.amazon.in/JUAREZ-Arp%C3%A9ggio-Sem...
# 179      https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 180      https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 181      https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 182      https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
#
# [182 rows x 7 columns]

# %% [markdown]
# Q3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
#import necessary librabies for webscraping with selenium

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests
from time import sleep

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
driver.get('https://www.google.co.in/')

# %%
image = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/div/div/div[1]/div/div[2]/a')
image.click()

# %%
search = driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')
search.send_keys('fruits')

# %%
search_b = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search_b.click()

# %%
# scrolling window 
driver.execute_script("window.scrollBy(0,1000)","")

# %%
# scrapinig urls of images
source = []
img_url = []
img_data = []
image = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')   
for im in image:
    source = im.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_url.append(source)

# %%
len(img_url)
# Out:
# 25

# %%
# downloading fruits images        
for i in range(len(img_url)):
    if i >= 10:
        break
    print('downloading image {0} of {1}'.format(i,10))
    response = requests.get(img_url[i])
    file= open(r"C:\Users\sahal\OneDrive\Pictures\fruits"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# downloading image 0 of 10
# downloading image 1 of 10
# downloading image 2 of 10
# downloading image 3 of 10
# downloading image 4 of 10
# downloading image 5 of 10
# downloading image 6 of 10
# downloading image 7 of 10
# downloading image 8 of 10
# downloading image 9 of 10

# %%
# downloading car images
search = driver.find_element(By.XPATH,'//input[@class="og3lId"]')
search.clear()
time.sleep(1)
search.send_keys('cars')       # entering car
time.sleep(2)                     
# click on search
clk = driver.find_element(By.XPATH,'//span[@class="n6h3Rc"]')
clk.click()
time.sleep(2)
# scrolling window 
driver.execute_script("window.scrollBy(0,1000)","")
time.sleep(2)
# scrapinig url of cars
source2 = []
car_url = []
image = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')   
for im in image:
    source2 = im.get_attribute('src')
    if source2 is not None:
        if(source2[0:4] == 'http'):
            car_url.append(source2)

# %%
# downloading car images        
for i in range(len(img_url)):
    if i >= 10:
        break
    print('downloading image {0} of {1}'.format(i,10))
    response = requests.get(car_url[i])
    file= open(r"C:\Users\sahal\OneDrive\Pictures\fruits"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# downloading image 0 of 10
# downloading image 1 of 10
# downloading image 2 of 10
# downloading image 3 of 10
# downloading image 4 of 10
# downloading image 5 of 10
# downloading image 6 of 10
# downloading image 7 of 10
# downloading image 8 of 10
# downloading image 9 of 10

# %%
# downloading ‘Machine Learning’ images
search = driver.find_element(By.XPATH,'//input[@class="og3lId"]')
search.clear()
time.sleep(1)
search.send_keys('Machine Learning')       # entering ‘Machine Learning’
time.sleep(2)                     
# click on search
clk = driver.find_element(By.XPATH,'//span[@class="n6h3Rc"]')
clk.click()
time.sleep(2)
# scrolling window 
driver.execute_script("window.scrollBy(0,1000)","")
time.sleep(2)
# scrapinig url of ‘Machine Learning’
source3 = []
Machine_Learning_url = []
mimage = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')   
for im in mimage:
    source3 = im.get_attribute('src')
    if source3 is not None:
        if(source3[0:4] == 'http'):
            Machine_Learning_url.append(source3)

# %%
# downloading ‘Machine Learning’ images        
for i in range(len(img_url)):
    if i >= 10:
        break
    print('downloading image {0} of {1}'.format(i,10))
    response = requests.get(Machine_Learning_url[i])
    file= open(r"C:\Users\sahal\OneDrive\Pictures\fruits"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# downloading image 0 of 10
# downloading image 1 of 10
# downloading image 2 of 10
# downloading image 3 of 10
# downloading image 4 of 10
# downloading image 5 of 10
# downloading image 6 of 10
# downloading image 7 of 10
# downloading image 8 of 10
# downloading image 9 of 10

# %%
# downloading Guitar images
search = driver.find_element(By.XPATH,'//input[@class="og3lId"]')
search.clear()
time.sleep(1)
search.send_keys('Guitar')       # entering Guitar
time.sleep(2)                     
# click on search
clk = driver.find_element(By.XPATH,'//span[@class="n6h3Rc"]')
clk.click()
time.sleep(2)
# scrolling window 
driver.execute_script("window.scrollBy(0,1000)","")
time.sleep(2)
# scrapinig url of Guitar
source4 = []
Guitar_url = []
gimage = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')   
for im in gimage:
    source4 = im.get_attribute('src')
    if source4 is not None:
        if(source4[0:4] == 'http'):
            Guitar_url.append(source4)

# %%
# downloading ‘Machine Learning’ images        
for i in range(len(Guitar_url)):
    if i >= 10:
        break
    print('downloading image {0} of {1}'.format(i,10))
    response = requests.get(Guitar_url[i])
    file= open(r"C:\Users\sahal\OneDrive\Pictures\fruits"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# downloading image 0 of 10
# downloading image 1 of 10
# downloading image 2 of 10
# downloading image 3 of 10
# downloading image 4 of 10
# downloading image 5 of 10
# downloading image 6 of 10
# downloading image 7 of 10
# downloading image 8 of 10
# downloading image 9 of 10

# %%
# downloading Cakes images
search = driver.find_element(By.XPATH,'//input[@class="og3lId"]')
search.clear()
time.sleep(1)
search.send_keys('Cakes')       # entering Cakes
time.sleep(2)                     
# click on search
clk = driver.find_element(By.XPATH,'//span[@class="n6h3Rc"]')
clk.click()
time.sleep(2)
# scrolling window 
driver.execute_script("window.scrollBy(0,1000)","")
time.sleep(2)
# scrapinig url of Guitar
source5 = []
Cakes_url = []
cimage = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')   
for im in cimage:
    source5 = im.get_attribute('src')
    if source5 is not None:
        if(source5[0:4] == 'http'):
            Cakes_url.append(source5)

# %%
# downloading ‘Machine Learning’ images        
for i in range(len(Cakes_url)):
    if i >= 10:
        break
    print('downloading image {0} of {1}'.format(i,10))
    response = requests.get(Cakes_url[i])
    file= open(r"C:\Users\sahal\OneDrive\Pictures\fruits"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# downloading image 0 of 10
# downloading image 1 of 10
# downloading image 2 of 10
# downloading image 3 of 10
# downloading image 4 of 10
# downloading image 5 of 10
# downloading image 6 of 10
# downloading image 7 of 10
# downloading image 8 of 10
# downloading image 9 of 10

# %% [markdown]
# Q4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#open the page in automated chrome browser

driver.get('http://www.flipkart.com/')
time.sleep(1)

# %%
#close popup window

try:
    popup = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
    popup.click()
except NoSuchElementException:
    print('Popup Window is not present')

# %%
# Finding Search bar

search=driver.find_element(By.XPATH,'//input[@class="_3704LK"]')

# Clearing any previous input in search bar

search.clear()

# Putting 'Oneplus Nord' to search button and click on seach

search.send_keys('Oneplus Nord')
button=driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
button.click()

# %%
# Making empty list to scrape data
brand =[]
smartphone =[]
colour =[]
ram=[]
rom =[]
primary_camera=[]
dual_camera=[]
display_size=[]
battery_capacity=[]
price =[]
url=[]

# %%
url_tags =driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in url_tags:
    x=i.get_attribute('href')
    url.append(x)

# %%
len(url)
# Out:
# 24

# %%
for i in url:
    driver.get(i)
    time.sleep(1)
    
    # Expanding specification table by clicking on read more button
    try:
        Read_more=driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        Read_more.click()
        
    except NoSuchElementException:
        print('NoSuchElementException Occur')
        pass
    
    # Extracting Brand Name
    try:
        brand_tags=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        brand.append(brand_tags.text.split()[0])
    
    except NoSuchElementException:
        brand.append('-')
        
    # Extracting smartphone Name
    try:
        smartphone_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')
        smartphone.append(smartphone_tags.text)
    
    except NoSuchElementException:
        smartphone.append('-')
        
    # Extracting Colour
    try:
        colour_tag =driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        colour.append(colour_tag.text)
    
    except NoSuchElementException:
        colour.append('-')
        
    # Extracting Storage ram
    try:
        ram_tag =driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[2]/td[2]/ul/li')
        ram.append(ram_tag.text)
        
    except NoSuchElementException:
        ram.append('-')
    
        
    # Extracting Storage rom
    try:
        rom_tag =driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]/ul/li')
        rom.append(rom_tag.text)
        
    except NoSuchElementException:
        rom.append('-')
        
    # Extracting Primary camera details
    p=[]
    try:
        camera_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[1]/td[2]/ul/li')
        p.append(camera_tags.text)
        for i in p:
            if i=='Yes':
                primary_camera.append('--')
            else:
                primary_camera.append(i)
                
    except NoSuchElementException:
        primary_camera.append('-')
                
        
    # Extracting Dual camera lens details
    try:
        dual_camera_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[2]/td[2]/ul/li')
        dual_camera.append(dual_camera_tags.text)
    
    except NoSuchElementException:
        dual_camera.append('-')
     
     
    # Extracting Display size details
    try:
        display_size_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table/tbody/tr[1]/td[2]/ul/li')
        display_size.append(display_size_tags.text)
    
    except NoSuchElementException:
        display_size.append('-')
      
      
    # Extracting battery capacity details
    l=[]
    try:
        battery_capacity_tags=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][7]/table/tbody/tr/td[2]/ul/li')
        l.append(battery_capacity_tags.text)
        for i in l:
            if len(i)== 8:
                battery_capacity.append(i)
            else:
                battery_capacity.append("--")
    
    except NoSuchElementException:
        battery_capacity.append('-')
        
        
    # Extracting price details
    try:
        price_tags=driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        price.append(price_tags.text)
    
    except NoSuchElementException:
        price.append('-')

# Creating DataFrame for scrapped

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(brand,smartphone,colour, ram,rom,primary_camera,dual_camera,display_size,battery_capacity,price,url))

data= pd.DataFrame (data_list,
    columns =['Brand_Name', 'Smartphone Name', 'Colour', 'RAM','Storage(ROM)', 'Primary Camera','Dual Camera',
              'Display Size', 'Battery Capacity','Price', 'URL'],
    index = pd.RangeIndex(start=1, stop=25, name='Sr. No.'))

#Print the required data

data.to_csv("oneplus_details.csv", index= False)

print("Details of each product listed in first page from flipkart.com:\n")
data
# Out:
# Details of each product listed in first page from flipkart.com:
#         Brand_Name    Smartphone Name        Colour    RAM Storage(ROM)  \
# Sr. No.
# 1          OnePlus  Nord CE 2 Lite 5G    Black Dusk   6 GB       128 GB
# 2          OnePlus  Nord CE 2 Lite 5G    Black Dusk   6 GB       128 GB
# 3          OnePlus  Nord CE 2 Lite 5G     Blue Tide   6 GB       128 GB
# 4          OnePlus   Nord CE2 Lite 5G     Blue Tide   8 GB       128 GB
# 5          OnePlus  Nord CE 2 Lite 5G    Black Dusk   6 GB       128 GB
# 6          OnePlus         Nord CE 5G  Charcoal Ink   8 GB       128 GB
# 7          OnePlus               Nord   Blue Marble  12 GB       256 GB
# 8          OnePlus               Nord   Blue Marble   6 GB        64 GB
# 9          OnePlus               Nord     Gray Onyx  12 GB       256 GB
# 10         OnePlus               Nord     Gray Onyx   6 GB        64 GB
# 11         OnePlus               Nord     Gray Onyx   8 GB       128 GB
# 12         OnePlus               Nord   Blue Marble   8 GB       128 GB
# 13         OnePlus  Nord CE 2 Lite 5G     Blue Tide   6 GB       128 GB
# 14         OnePlus  Nord CE 2 Lite 5G     Blue Tide   6 GB       128 GB
# 15         OnePlus  Nord CE 2 Lite 5G    Black Dusk   8 GB       128 GB
# 16         OnePlus         Nord 2T 5G      Jade Fog   8 GB       128 GB
# 17         OnePlus          Nord 2 5G     Blue Haze   8 GB       128 GB
# 18         OnePlus   Nord CE2 Lite 5G     Blue Tide   8 GB       128 GB
# 19         OnePlus          Nord 2 5G   Gray Sierra  12 GB       256 GB
# 20         OnePlus       Nord CE 2 5G   Bahama Blue   8 GB       128 GB
# 21         OnePlus         Nord 2T 5G   Gray Shadow   8 GB       128 GB
# 22         OnePlus         Nord 2T 5G   Gray Shadow  12 GB       256 GB
# 23         OnePlus         Nord 2T 5G      Jade Fog  12 GB       256 GB
# 24         OnePlus         Nord 2T 5G      Jade Fog  12 GB       256 GB
#
#            Primary Camera                 Dual Camera          Display Size  \
# Sr. No.
# 1        64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 2        64MP Rear Camera              Primary Camera  16.74 cm (6.59 inch)
# 3        64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 4        64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 5        64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 6        64MP Rear Camera              Primary Camera  16.33 cm (6.43 inch)
# 7                      --                  48MP + 8MP  16.36 cm (6.44 inch)
# 8                      --                  48MP + 8MP  16.36 cm (6.44 inch)
# 9                      --                  48MP + 8MP  16.36 cm (6.44 inch)
# 10                     --                  48MP + 8MP  16.36 cm (6.44 inch)
# 11                     --                  48MP + 8MP  16.36 cm (6.44 inch)
# 12                     --                  48MP + 8MP  16.36 cm (6.44 inch)
# 13                     --            64MP Rear Camera  16.74 cm (6.59 inch)
# 14       64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 15       64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 16       50MP Rear Camera              Primary Camera   17.02 cm (6.7 inch)
# 17       50MP Rear Camera              Primary Camera  16.33 cm (6.43 inch)
# 18       64MP Rear Camera  Primary & Secondary Camera  16.74 cm (6.59 inch)
# 19       50MP Rear Camera              Primary Camera  16.33 cm (6.43 inch)
# 20       64MP Rear Camera  Primary & Secondary Camera  16.33 cm (6.43 inch)
# 21       50MP Rear Camera  Primary & Secondary Camera   17.02 cm (6.7 inch)
# 22       50MP Rear Camera              Primary Camera   17.02 cm (6.7 inch)
# 23       50MP Rear Camera              Primary Camera   17.02 cm (6.7 inch)
# 24       50MP Rear Camera  Primary & Secondary Camera   17.02 cm (6.7 inch)
#
#         Battery Capacity    Price  \
# Sr. No.
# 1               5000 mAh  ₹19,999
# 2               5000 mAh  ₹19,899
# 3               5000 mAh  ₹19,999
# 4               5000 mAh  ₹21,900
# 5               5000 mAh  ₹19,999
# 6               4500 mAh  ₹24,990
# 7                     --  ₹29,999
# 8                     --  ₹24,999
# 9                     --  ₹29,999
# 10                    --  ₹24,999
# 11                    --  ₹27,999
# 12                    --  ₹27,999
# 13                    --  ₹19,800
# 14              5000 mAh  ₹19,999
# 15              5000 mAh  ₹21,990
# 16              4500 mAh  ₹28,920
# 17              4500 mAh  ₹29,799
# 18              5000 mAh  ₹21,990
# 19              4500 mAh  ₹34,990
# 20              4500 mAh  ₹24,797
# 21              4500 mAh  ₹28,900
# 22              4500 mAh  ₹31,999
# 23              4500 mAh  ₹31,999
# 24              4500 mAh  ₹33,890
#
#                                                        URL
# Sr. No.
# 1        https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 2        https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 3        https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 4        https://www.flipkart.com/oneplus-nord-ce2-lite...
# 5        https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 6        https://www.flipkart.com/oneplus-nord-ce-5g-ch...
# 7        https://www.flipkart.com/oneplus-nord-blue-mar...
# 8        https://www.flipkart.com/oneplus-nord-blue-mar...
# 9        https://www.flipkart.com/oneplus-nord-gray-ony...
# 10       https://www.flipkart.com/oneplus-nord-gray-ony...
# 11       https://www.flipkart.com/oneplus-nord-gray-ony...
# 12       https://www.flipkart.com/oneplus-nord-blue-mar...
# 13       https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 14       https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 15       https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 16       https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 17       https://www.flipkart.com/oneplus-nord-2-5g-blu...
# 18       https://www.flipkart.com/oneplus-nord-ce2-lite...
# 19       https://www.flipkart.com/oneplus-nord-2-5g-gra...
# 20       https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 21       https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 22       https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 23       https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 24       https://www.flipkart.com/oneplus-nord-2t-5g-ja...

# %% [markdown]
# Q5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#open the page in automated chrome browser

driver.get('https://www.google.co.in/maps')
time.sleep(1)

# %%
# Finding Search bar

search=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]')

# Clearing any previous input in search bar

search.clear()

# Putting 'Kolkata' to search button and click on seach

search.send_keys('Kolkata')
button=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button')
button.click()

# %%
# finding the current url

current_URL=driver.current_url

# %%
# finding total location from URL

if "@" in current_URL:
        loc = current_URL.split('@')[1].split(',*/data')[0].split(',')
loc
# Out:
# ['22.6757521',
#  '88.0495295',
#  '10z/data=!3m1!4b1!4m5!3m4!1s0x39f882db4908f667:0x43e330e68f6c2cbc!8m2!3d22.572646!4d88.363895']

# %%
# scraping latitude and longitude from URL

try:
    if "@" in current_URL:
        loc = current_URL.split('@')[1].split(',*/data')[0].split(',')
        print('Latitude of given Location:',loc[0])
        print('Longitude of given Location:',loc[1])
except:
    print('Location details is not found in URL')
# Out:
# Latitude of given Location: 22.6757521
# Longitude of given Location: 88.0495295

# %% [markdown]
# 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#open the page in automated chrome browser

driver.get('https://trak.in')
time.sleep(2)

# %%
# Clicking 'funding deals'

funding_deals_tags = driver.find_element(By.XPATH,'//li[@id="menu-item-51510"]/a')
x= funding_deals_tags.get_attribute('href')
driver.get(x)

# %%
# serial no
s_no = []
rank =  driver.find_elements(By.XPATH,'//td[@class="column-1"]')
for i in rank:
    s_no.append(i.text)
s_no=s_no[5:29]

# %%
# date
date = []
d = driver.find_elements(By.XPATH,'//td[@class="column-2"]')
for i in d:
    date.append(i.text)
date = date[5:29]

# %%
# startup name
s_name = []
s = driver.find_elements(By.XPATH,'//td[@class="column-3"]')
for i in s:
    s_name.append(i.text)
s_name = s_name[5:29]

# %%
# industary/vertical
industary = []
ind = driver.find_elements(By.XPATH,'//td[@class="column-4"]')
for i in ind:
    industary.append(i.text)
industary = industary[5:29]

# %%
# sub-vertical
sub = []
su = driver.find_elements(By.XPATH,'//td[@class="column-5"]')
for i in su:
    sub.append(i.text)
sub = sub[5:29]

# %%
# city/location
city = []
ci = driver.find_elements(By.XPATH,'//td[@class="column-6"]')
for i in ci:
    city.append(i.text)
city = city[5:29]

# %%
# investor's name
invertor = []
inv = driver.find_elements(By.XPATH,'//td[@class="column-7"]')
for i in inv:
    invertor.append(i.text)
invertor = invertor[5:29]

# %%
# investment type
investment = []
invs = driver.find_elements(By.XPATH,'//td[@class="column-8"]')
for i in invs:
    investment.append(i.text)
investment = investment[5:29]

# %%
# amount (in USD)
amount = []
am = driver.find_elements(By.XPATH,'//td[@class="column-9"]')
for i in am:
    amount.append(i.text)
amount = amount[5:29]

# %%
# creating dataframe
df = pd.DataFrame({'serial no':s_no,'date':date,'startup name':s_name,'industary/vertical':industary,'sub-vertical':sub,'city/location':city,'investor name':invertor,'investment type':investment,'amount (in USD)':amount},index=list(range(1,len(city)+1)))
print('Indian Startup Funding & Investment Chart [2021] from JAN to MARCH in descending order')
df
# Out:
# Indian Startup Funding & Investment Chart [2021] from JAN to MARCH in descending order
#    serial no        date            startup name      industary/vertical  \
# 1          1  04/03/2021               DealShare              E-commerce
# 2          2  31/03/2021                Uniphore              Technology
# 3          3  30/03/2021                   Dunzo              E-commerce
# 4          4  30/03/2021                  BYJU’S                Edu-tech
# 5          5  23/03/2021             SkilloVilla                Edu-tech
# 6          6  25/03/2021                CityMall              E-commerce
# 7          7  26/03/2021                   DotPe                 FinTech
# 8          1  11/02/2021                Doubtnut                Edu Tech
# 9          2  22/02/2021                  Zomato             Hospitality
# 10         3  19/02/2021               Fingerlix             Hospitality
# 11         4  17/02/2021                   Zolve                 FinTech
# 12         5  15/02/2021               KreditBee                 Finance
# 13         6  12/02/2021               Pepperfry              E-commerce
# 14         7  12/02/2021                 Grofers              E-Commerce
# 15         8  09/02/2021                 Nothing              Technology
# 16         9  09/02/2021             SplashLearn                  EdTech
# 17         1  15/01/2021         Digit Insurance      Financial Services
# 18         2  28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 19         3  19/01/2021                  DeHaat        AgriTech Startup
# 20         4  19/01/2021               Darwinbox                    SaaS
# 21         5  18/01/2021                   mfine     Health Tech Startup
# 22         6  18/01/2021                   Udayy                  EdTech
# 23         7  11/01/2021           True Elements            Food Startup
# 24         8  13/01/2021                   Saveo          B2B E-commerce
#
#                                          sub-vertical      city/location  \
# 1                            Online shopping platform  Jaipur, Rajasthan
# 2             Conversational Service Automation (CSA)          Palo Alto
# 3                            Hyper-local delivery app          Bengaluru
# 4                                     Online tutoring          Bengaluru
# 5                 Career and job-oriented upskilling.          Bengaluru
# 6        Social ecommerce and online grocery platform            Gurgaon
# 7   Commerce and payments platform to offline ente...            Gurgaon
# 8                                 E-Learning Platform            Gurgaon
# 9                       Online Food Delivery Platform            Gurgaon
# 10                      Semi-cooked food delivery app             Mumbai
# 11                             Global Neobank Venture             Mumbai
# 12                           Digital lending platform          Bengaluru
# 13                        Multi-brand furniture brand             Mumbai
# 14                                 Online supermarket            Gurgaon
# 15                        Consumer Technology Venture             London
# 16                      Game-based learning programme            Gurgaon
# 17                                 Insurance Services          Bengaluru
# 18      Shave care, beard care, and skincare products          New Delhi
# 19  online marketplace for farm products and services              Patna
# 20                                            HR Tech             Mumbai
# 21                 AI-powered telemedicine mobile app          Bengaluru
# 22     Online learning platform for kids in class 1-5            Gurgaon
# 23                      Whole Food plant based Nashta               Pune
# 24                                         Pharmacies          Bengaluru
#
#                                         investor name investment type  \
# 1                                     Innoven Capital  Debt Financing
# 2                           Sorenson Capital Partners        Series D
# 3                           Krishtal Advisors Pte Ltd        Series E
# 4          MC Global Edtech, B Capital, Baron, others        Series F
# 5                               Titan Capital, others            Seed
# 6                                      Accel Partners        Series A
# 7                                                PayU        Series A
# 8   SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 9                                  Tiger Global, Kora         Venture
# 10           Rhodium Trust, Accel Partners and Swiggy        Series C
# 11     Accel Partners and Lightspeed Venture Partners            Seed
# 12  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 13                                    InnoVen Capital  Debt Financing
# 14                         SoftBank Vision Fund (SVF)     Unspecified
# 15                                                 GV        Series A
# 16                                       Owl Ventures        Series C
# 17   A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 18                                  Reckitt Benckiser         Venture
# 19                                    Prosus Ventures        Series C
# 20                                Salesforce Ventures            Seed
# 21                         Heritas Capital Management   Venture Round
# 22                                    Sequoia Capital    Seed Funding
# 23                              SIDBI Venture Capital          Series
# 24          Matrix Partners India, RTP Global, others            Seed
#
#    amount (in USD)
# 1      250,000,000
# 2      140,000,000
# 3        8,000,000
# 4      460,000,000
# 5      300,000,000
# 6       11,000,000
# 7       27,500,000
# 8        2,500,000
# 9      250,000,000
# 10    2,747,045.20
# 11     1,50,00,000
# 12      75,000,000
# 13       4,773,958
# 14      55,000,000
# 15      15,000,000
# 16      18,000,000
# 17     1,80,00,000
# 18    6,172,258.50
# 19      30,000,000
# 20      15,000,000
# 21      16,000,000
# 22      15,000,000
# 23     100,000,000
# 24       4,000,000

# %% [markdown]
# Q7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
#import necessary librabies for webscraping with selenium

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests
from time import sleep

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#open the page in automated chrome browser

driver.get('https://www.digit.in')
time.sleep(2)

# %%
# Clicking on top 10 option button in menu bar

top10= driver.find_element(By.XPATH,'//div[@class="menu"]/ul/li[4]/a')
top10.click()
time.sleep(2)

# Clicking on Laptop
lap= driver.find_element(By.XPATH,'//div[@class="categoty_list"]/button[2]')
lap.click()

# Clicking on Best gaming laptops

gaming_lap =driver.find_element(By.XPATH,'//div[@id="laptops"]/div[3]/a').get_attribute('href')
driver.get(gaming_lap)
time.sleep(3)

# %%
# Making Empty list for scraping data

laptop_model =[]
processor =[]
display = []
OS =[]
memory =[]
graphics_processor =[]
dimension =[]
weight =[]
url=[]

# %%
# Extracting Laptop model

laptop_tags =driver.find_elements(By.XPATH, '//div[@class="left_side"]/a/h3')
for i in laptop_tags:
    laptop_model.append(i.text)

# Extracting processor

processor_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]')
for i in processor_tags:
    processor.append(i.text)
    
# Extracting display

display_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]')
for i in display_tags:
    display.append(i.text)

# Extracting OS

OS_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]')
for i in OS_tags:
    OS.append(i.text)    

# Extracting memory

memory_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
for i in memory_tags:
    memory.append(i.text)
    
# Extracting graphics_processor

graphics_processor_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
for i in graphics_processor_tags:
    graphics_processor.append(i.text)
    
# Extracting dimension

dimension_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in dimension_tags:
    dimension.append(i.text.split("&")[0])
    
# Extracting weight

weight_tags =driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in weight_tags:
    weight.append(i.text.split("&")[1])
    
# Extracting url details

url_tags =driver.find_elements(By.XPATH,'//div[@class="left_side"]/a')
for i in url_tags:
    url.append(i.get_attribute("href"))

# %%
# Creating DataFrame for scrapped data

data_list= list(zip(laptop_model,processor,display,OS,memory,graphics_processor,dimension,weight,url))

data= pd.DataFrame (data_list,
    columns =['Laptop Model', 'Processor', 'Display', 'OS','Memory','Graphics Processor',
              'Dimension', 'Weight', 'URL'], index= pd.RangeIndex(start=1, stop=11, name='Sr. No.'))

#Print the required data

data.to_csv("Digit_laptop_details.csv", index= False)

print("Details of all the available details of best gaming laptops from digit.in:\n")
data
# Out:
# Details of all the available details of best gaming laptops from digit.in:
#                                           Laptop Model  \
# Sr. No.
# 1                                 MSI Titan GT77-12UHS
# 2                                     Alienware X17 R2
# 3                Acer Predator Triton 500 SE PT516-52s
# 4                              Omen By HP (16-B1371TX)
# 5        Acer Predator Helios 300 AN515-45 (NH.QBRSI.0
# 6                           MSI Delta 15 (A5EFK-083IN)
# 7                              Omen By HP (16-C0141AX)
# 8                    Lenovo Legion 5i Pro (82RF00MGIN)
# 9        Alienware M15 R5 Ryzen Edition Icc-C780001win
# 10                    Lenovo Slim 7 Gen 6 (82K8002JIN)
#
#                                                  Processor  \
# Sr. No.
# 1         12th Gen Intel Core i9-12900HX 16 core processor
# 2        12th Gen Intel Core i9-12900H 14 core processo...
# 3        12th Gen Intel Core i7-12700H 14 core processo...
# 4        12th Gen Intel Core i7-12700H 14 core processo...
# 5                      AMD Ryzen 9-5900HX 8 core processor
# 6        AMD 5th Gen Ryzen 9-5900HX 8 core processor wi...
# 7        AMD Ryzen™ 9 5900HX 8 core processor with 3.3 ...
# 8        12th Gen Intel Core i7-12700H 14 core processo...
# 9        AMD Ryzen R7-5800H 8 core processor with 4.40 ...
# 10       Lenovo Ryzen 7-5800H processor with 3.2 GHz cl...
#
#                                                  Display               OS  \
# Sr. No.
# 1        17.3″ (3840 x 2160) screen, 120 Hz refresh rate  Windows 11 Home
# 2        17.3″ (1920 x 1080) screen, 360 Hz refresh rate  Windows 11 Home
# 3          16″ (2560 x 1600) screen, 240 Hz refresh rate  Windows 11 Home
# 4                             16.1″ (2560 x 1440) screen  Windows 11 Home
# 5        15.6″ (2560 x 1440) screen, 165 Hz refresh rate  Windows 11 Home
# 6         15.6″ (1920 x 1080) screen, 240Hz refresh rate  Windows 11 Home
# 7                             16.1″ (2560 x 1440) screen  Windows 11 Home
# 8          16″ (2560 x 1600) screen, 165 Hz refresh rate  Windows 11 Home
# 9         15.6″ (1920 x 1080) screen, 165Hz refresh rate  Windows 11 Home
# 10                     15.6″ screen, 165 Hz refresh rate  Windows 11 Home
#
#                               Memory  \
# Sr. No.
# 1          64 GB DDR5 RAM & 2 TB SSD
# 2          32 GB DDR5 RAM & 1 TB SSD
# 3          32 GB DDR5 RAM & 2 TB SSD
# 4           8 GB DDR5 RAM & 1 TB SSD
# 5        16 GB DDR4 RAM & 512 GB SSD
# 6          16 GB DDR4 RAM & 1 TB SSD
# 7         16 GB DDR4 RAM & 1 TB NVMe
# 8          16 GB DDR5 RAM & 1 TB SSD
# 9        16 GB DDR4 RAM & 512 GB SSD
# 10         16 GB DDR4 RAM & 1 TB SSD
#
#                                         Graphics Processor  \
# Sr. No.
# 1        16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...
# 2        16 GB DDR6 NVIDIA GEFORCE RTX 3080 Ti Graphics...
# 3        8 GB DDR6 NVIDIA GeForce RTXTM 3070 Ti Graphic...
# 4         8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card
# 5          8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card
# 6             10 GB DDR6 AMD Radeon RX 6700M Graphics card
# 7            8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card
# 8          6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 9          6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 10       6 GB DDR6 NVIDIA GeForce 3060 Max-Q Graphics card
#
#                                    Dimension           Weight  \
# Sr. No.
# 1               397 x 330 x 23 mm dimension     3.3 kg weight
# 2               299 x 359 x 21 mm dimension    2.96 kg weight
# 3             358 x 262 x 19.9 mm dimension     2.4 kg weight
# 4               369 x 248 x 23 mm dimension    2.32 kg weight
# 5             363 x 255 x 23.9 mm dimension     2.4 kg weight
# 6               357 x 247 x 19 mm dimension     1.9 kg weight
# 7           36.92 x 24.8 x 2.3 mm dimension     2.3 kg weight
# 8               360 x 264 x 20 mm dimension    2.49 kg weight
# 9        356.2 x 272.5 x 22.85 mm dimension    2.69 kg weight
# 10              356 x 252 x 16 mm dimension     1.9 kg weight
#
#                                                        URL
# Sr. No.
# 1        https://www.digit.in/laptops/msi-titan-gt77-12...
# 2        https://www.digit.in/laptops/dell-new-alienwar...
# 3        https://www.digit.in/laptops/acer-predator-tri...
# 4        https://www.digit.in/laptops/omen-by-hp-16-b13...
# 5        https://www.digit.in/laptops/acer-nitro-5-an51...
# 6        https://www.digit.in/laptops/msi-delta-15-5th-...
# 7        https://www.digit.in/laptops/hp-omen-16-c0141a...
# 8        https://www.digit.in/laptops/lenovo-legion-5-p...
# 9        https://www.digit.in/laptops/dell-alienware-m1...
# 10       https://www.digit.in/laptops/lenovo-legion-s7-...

# %% [markdown]
# Q8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

#open the page in automated chrome browse

driver.get('https://www.forbes.com/billionaires/')
time.sleep(2)

# %%
# rank
rank = []
r = driver.find_elements(By.XPATH,'//div[@class="rank"]')
for i in r:
    rank.append(i.text)

# %%
len(rank)
# Out:
# 200

# %%
# name
name = []
n = driver.find_elements(By.XPATH,'//div[@class="personName"]')
for i in n:
    name.append(i.text)

# %%
len(name)
# Out:
# 200

# %%
# net worth
worth = []
w = driver.find_elements(By.XPATH,'//div[@class="netWorth"]')
for i in w:
    worth.append(i.text)

# %%
len(worth)
# Out:
# 200

# %%
# country
country = []
c = driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
for i in c:
    country.append(i.text)

# %%
len(country)
# Out:
# 200

# %%
# age 
age = []
a = driver.find_elements(By.XPATH,'//div[@class="age"]')
for i in a:
    age.append(i.text)

# %%
len(age)
# Out:
# 200

# %%
# source
source = []
s = driver.find_elements(By.XPATH,'//span[@class="source-text"]')
for i in s :
    source.append(i.text)

# %%
len(source)
# Out:
# 200

# %%
# industary
industaries = []
i = driver.find_elements(By.XPATH,'//div[@class="category"]')
for k in i:
    industaries.append(k.text)

# %%
len(industaries)
# Out:
# 200

# %%
df = pd.DataFrame({"Rank":rank, "Name":name, "Net worth":worth, "Age":age, "Country":country, "Source":source, "Industry":industaries})
print('The Richest People In The World ')
df
# Out:
# The Richest People In The World
#      Rank                      Name Net worth Age        Country  \
# 0      1.                 Elon Musk    $219 B  50  United States
# 1      2.                Jeff Bezos    $171 B  58  United States
# 2      3.  Bernard Arnault & family    $158 B  73         France
# 3      4.                Bill Gates    $129 B  66  United States
# 4      5.            Warren Buffett    $118 B  91  United States
# ..    ...                       ...       ...  ..            ...
# 195  192.    Marcel Herrmann Telles   $10.3 B  72         Brazil
# 196  197.                Leon Black     $10 B  70  United States
# 197  197.                Joe Gebbia     $10 B  40  United States
# 198  197.              David Geffen     $10 B  79  United States
# 199  197.                Yu Renrong     $10 B  56          China
#
#                     Source               Industry
# 0            Tesla, SpaceX             Automotive
# 1                   Amazon             Technology
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4       Berkshire Hathaway  Finance & Investments
# ..                     ...                    ...
# 195                   beer        Food & Beverage
# 196         private equity  Finance & Investments
# 197                 Airbnb             Technology
# 198  movies, record labels  Media & Entertainment
# 199         semiconductors          Manufacturing
#
# [200 rows x 7 columns]

# %% [markdown]
# Q9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video

# %%
#import necessary librabies for webscraping with selenium

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import requests
from time import sleep

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
driver.get('https://www.youtube.com/watch?v=PncsrR_MoSw')

# %%
comment = []
time = []
upvote = []

# %%
# extracting comments
for  _ in range(50):
    driver.execute_script("window.scrollBy(0,50)")
    try:
        Comment = driver.find_elements(By.XPATH,'//div[@class="style-scope ytd-expander"]')
        for i in Comment[0:500]:
            comment.append(i.text)
    except NoSuchElementException:
        comment.append('-')
    # time 
    try: 
        Time = driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
        for j in Time[0:500]:
            time.append(j.text)
    except NoSuchElementException:
        time.append('-')
    # upvote
    try:
        Upvote = driver.find_elements(By.XPATH,'//span[@id="vote-count-middle"]')
        for k in Upvote[0:500]:
            upvote.append(k.text)
    except NoSuchElementException:
        upvote.append('-')

# %%
comment=comment[0:500]

# %%
upvote=upvote[0:500]

# %%
time=time[0:500]

# %%
df = pd.DataFrame({"comment":comment,"Time":time,"Upvote":upvote},index=list(range(1,len(time)+1)))
print('comments on youtube video')
df
# Out:
# comments on youtube video
#                                                comment  \
# 1
# 2
# 3
# 4
# 5
# ..                                                 ...
# 496
# 497
# 498  സഫാരി ചാനൽ ഉണ്ടായതിനുപിന്നിലെ കഥ : https://you...
# 499  27 വർഷമായി ഈ നഗരത്തിന്റെ ഭാഗമായി ഇപ്പോഴും തുടര...
# 500  ലേബർ ഇന്ത്യയിൽ തുടങ്ങിയ പ്രണയമാണ് ഇപ്പോഴും തുട...
#
#                                 Time Upvote
# 1                             Safari    471
# 2    https://www.safaritvchannel.com   2.7K
# 3                                      1.5K
# 4                                       589
# 5                                      1.8K
# ..                               ...    ...
# 496             3 years ago (edited)      3
# 497                      3 years ago      1
# 498             1 month ago (edited)      5
# 499                      3 years ago     49
# 500                             #SgK     23
#
# [500 rows x 3 columns]

# %% [markdown]
#   Q 10)  Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
# opening the url
driver.get('https://www.hostelworld.com/')

# %%
# Enter the location
loc = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[1]/div/div/div[4]/div/div[2]/div/div[1]/div/div/div/input')
loc.clear()
loc.send_keys("London")

# %%
#choosing frist option
driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[1]/div/div/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div').click()

# %%
# Clicking on Let's go!
driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[1]/div/div/div[4]/div/div[2]/div/div[5]/button').click()

# %%
# Scrapping required details: 
#scraping hostel name, distance from city centre, ratings, total reviews, overall reviews, 
#privates from price, dorms from price, facilities and property description.

#Creating Empty Lists
Name = []
Distance = []
Rating = []
Reviews = []
Overall = []
Privates = []
Dorms = []
Facilities = []
Property = []


# Scraping Names 
N = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
for i in N:
    Name.append(i.text)
    
#Scrapping distance from city centre
try:
    D = driver.find_elements(By.XPATH,'//span[@class="description"]')
    for i in D:
        Distance.append(i.text)
except NoSuchElementException:
    Distance.append("-")

#Scrapping ratings
try:
    RT = driver.find_elements(By.XPATH,'//div[@class="rating rating-summary-container big"]')
    for i in RT:
        Rating.append(i.text[:][0:3])
except NoSuchElementException:
    Rating.append("-")
    
#Scrapping total reviews
try:
    RV = driver.find_elements(By.XPATH,'//div[@class="reviews"]')
    for i in RV:
        Reviews.append(i.text)
except NoSuchElementException:
    Reviews.append("-")
    
#Scrapping overall reviews
try:
    O = driver.find_elements(By.XPATH,'//div[@class="keyword"]')
    for i in O:
        Overall.append(i.text)
except NoSuchElementException:
    Overall.append("-")
    
#Scrapping privates from price
P = driver.find_elements(By.XPATH,'//div[@class="price-col"]')[0::2]
for i in P:
    Privates.append(i.text.replace('\n',': ').replace('No Privates Available','NaN'))
       
#Scrapping Dorms from price
P = driver.find_elements(By.XPATH,'//div[@class="price-col"]')[1::2]
for i in P:
    Dorms.append(i.text.replace('\n',': ').replace('No Dorms Available','NaN'))
    
#Scrapping Facilities
try:
    F = driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
    for i in F:
        Facilities.append(i.text.replace('\n',', '))
except NoSuchElementException:
    Facilities.append("-")
    
#Scrapping property description.
try:
    PD = driver.find_elements(By.XPATH,'//div[@class="rating-factors prop-card-tablet rating-factors small"]')
    for i in PD:
        Property.append(i.text.replace('\n',', '))
except NoSuchElementException:
    Property.append("-")

# %%
print(len(Name),len(Distance),len(Rating),len(Reviews),len(Privates),len(Dorms),len(Facilities),len(Property))
# Out:
# 30 30 30 30 30 30 30 30

# %%
#scraping hostel name, distance from city centre, ratings, total reviews, overall reviews, 
#privates from price, dorms from price, facilities and property description.
# Creating Data Frame 
df = pd.DataFrame({'Hostel name':Name,
                   'Distance from city centre':Distance,
                   'Rating':Rating,
                   'Total reviews':Reviews,
                   'Privates from price':Privates,
                   'Dorms from price':Dorms,
                   'Facilities':Facilities,
                   'Property description':Property})
df
# Out:
#                                 Hostel name         Distance from city centre  \
# 0                  St Christopher's Village   Hostel - 1.8km from city centre
# 1        St Christopher's Oasis-Female Only   Hostel - 1.8km from city centre
# 2         Safestay London Elephant & Castle   Hostel - 1.7km from city centre
# 3                   Hostel One Notting Hill   Hostel - 5.5km from city centre
# 4                Smart Hyde Park Inn Hostel     Hostel - 5km from city centre
# 5                        London Backpackers  Hostel - 11.9km from city centre
# 6                          NX London Hostel   Hostel - 6.1km from city centre
# 7                             Selina Camden   Hostel - 5.5km from city centre
# 8           St Christopher's Shepherds Bush     Hostel - 7km from city centre
# 9              St Christopher's Hammersmith   Hostel - 7.5km from city centre
# 10               St Christopher's Greenwich   Hostel - 7.6km from city centre
# 11                         Generator London     Hostel - 3km from city centre
# 12                        Bell House Hostel   Hostel - 4.2km from city centre
# 13           PubLove @ The Crown, Battersea   Hostel - 4.7km from city centre
# 14               PubLove @ The Rose & Crown   Hostel - 1.6km from city centre
# 15  Safestay London Kensington Holland Park   Hostel - 5.9km from city centre
# 16                   London Waterloo Hostel   Hostel - 0.7km from city centre
# 17                  Saint James Backpackers   Hostel - 5.5km from city centre
# 18                     Urbany Hostel London   Hostel - 5.4km from city centre
# 19                           Colliers Hotel    Hotel - 2.1km from city centre
# 20                      Britannia Inn Hotel   Hotel - 14.5km from city centre
# 21                       Tony's House Hotel    Hotel - 4.3km from city centre
# 22                      The W14 Hotel & Bar    Hotel - 6.5km from city centre
# 23                       London House Hotel    Hotel - 5.3km from city centre
# 24                    Belgrave Hotel London    Hotel - 2.2km from city centre
# 25                            Hanover Hotel    Hotel - 2.1km from city centre
# 26                         Park Hotel Essex   Hotel - 24.1km from city centre
# 27                             Victor Hotel    Hotel - 1.8km from city centre
# 28                                Kip Hotel    Hotel - 6.8km from city centre
# 29                          Cranbrook Hotel   Hotel - 14.8km from city centre
#
#    Rating        Total reviews                Privates from price  \
# 0     8.2  11616 Total Reviews                                NaN
# 1     8.3    699 Total Reviews  Privates From: Rs14725.41 Rs13253
# 2     7.1   4606 Total Reviews                                NaN
# 3     9.3   1543 Total Reviews             Privates From: Rs15605
# 4     7.5   6390 Total Reviews                                NaN
# 5     8.1   4351 Total Reviews                                NaN
# 6     7.5   1288 Total Reviews                                NaN
# 7     8.0     38 Total Reviews             Privates From: Rs43771
# 8     7.5    726 Total Reviews                                NaN
# 9     7.9   4143 Total Reviews                                NaN
# 10    6.9   3266 Total Reviews                                NaN
# 11    7.8   7219 Total Reviews             Privates From: Rs15417
# 12    NEW      2 Total Reviews             Privates From: Rs12665
# 13    7.0    268 Total Reviews                                NaN
# 14    7.7    157 Total Reviews                                NaN
# 15    6.7   1349 Total Reviews                                NaN
# 16    5.8   2518 Total Reviews                                NaN
# 17    6.9   1838 Total Reviews             Privates From: Rs17594
# 18    9.2    508 Total Reviews             Privates From: Rs18122
# 19    6.6      8 Total Reviews             Privates From: Rs10385
# 20    8.7     23 Total Reviews             Privates From: Rs33721
# 21    5.1    410 Total Reviews             Privates From: Rs16781
# 22    8.5    282 Total Reviews             Privates From: Rs13425
# 23    9.4   1382 Total Reviews  Privates From: Rs36989.64 Rs25893
# 24    5.4     10 Total Reviews             Privates From: Rs12349
# 25    No      46 Total Reviews             Privates From: Rs21310
# 26    8.0    109 Total Reviews             Privates From: Rs33721
# 27    No       2 Total Reviews             Privates From: Rs16794
# 28    6.6     54 Total Reviews             Privates From: Rs12919
# 29    No      58 Total Reviews             Privates From: Rs24539
#
#                 Dorms from price  \
# 0   Dorms From: Rs4136.94 Rs3723
# 1   Dorms From: Rs5366.88 Rs4830
# 2             Dorms From: Rs5528
# 3                            NaN
# 4   Dorms From: Rs3880.83 Rs3493
# 5             Dorms From: Rs4275
# 6   Dorms From: Rs5704.89 Rs4564
# 7                            NaN
# 8   Dorms From: Rs4839.87 Rs4356
# 9   Dorms From: Rs5120.97 Rs4609
# 10  Dorms From: Rs4242.49 Rs3818
# 11            Dorms From: Rs5956
# 12            Dorms From: Rs4275
# 13            Dorms From: Rs6649
# 14            Dorms From: Rs6966
# 15            Dorms From: Rs4360
# 16            Dorms From: Rs5809
# 17            Dorms From: Rs6871
# 18                           NaN
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# 28                           NaN
# 29                           NaN
#
#                                            Facilities  \
# 0     Free WiFi, Follows Covid-19 sanitation guidance
# 1     Free WiFi, Follows Covid-19 sanitation guidance
# 2     Free WiFi, Follows Covid-19 sanitation guidance
# 3                                           Free WiFi
# 4                                           Free WiFi
# 5     Free WiFi, Follows Covid-19 sanitation guidance
# 6                           Free WiFi, Free Breakfast
# 7                                           Free WiFi
# 8     Free WiFi, Follows Covid-19 sanitation guidance
# 9     Free WiFi, Follows Covid-19 sanitation guidance
# 10    Free WiFi, Follows Covid-19 sanitation guidance
# 11    Free WiFi, Follows Covid-19 sanitation guidance
# 12                                          Free WiFi
# 13    Free WiFi, Follows Covid-19 sanitation guidance
# 14    Free WiFi, Follows Covid-19 sanitation guidance
# 15                                          Free WiFi
# 16    Free WiFi, Follows Covid-19 sanitation guidance
# 17  Free WiFi, Free Breakfast, Follows Covid-19 sa...
# 18    Free WiFi, Follows Covid-19 sanitation guidance
# 19               Follows Covid-19 sanitation guidance
# 20  Free Breakfast, Follows Covid-19 sanitation gu...
# 21                                     Free Breakfast
# 22                          Free WiFi, Free Breakfast
# 23                                          Free WiFi
# 24                          Free WiFi, Free Breakfast
# 25                          Free WiFi, Free Breakfast
# 26  Free Breakfast, Follows Covid-19 sanitation gu...
# 27                                          Free WiFi
# 28                                          Free WiFi
# 29  Free Breakfast, Follows Covid-19 sanitation gu...
#
#                                  Property description
# 0   Perfect Location, Superb Staff, Excellent Clea...
# 1   Perfect Location, Superb Staff, Fantastic Clea...
# 2   Wonderful Location, Brilliant Staff, Awesome C...
# 3   Perfect Location, Superb Staff, Fantastic Clea...
# 4   Perfect Location, Marvellous Staff, Awesome Cl...
# 5   Wonderful Location, Superb Staff, Excellent Cl...
# 6   Perfect Location, Marvellous Staff, Awesome Cl...
# 7   Perfect Location, Superb Staff, Fantastic Clea...
# 8   Perfect Location, Superb Staff, Awesome Cleanl...
# 9   Perfect Location, Superb Staff, Excellent Clea...
# 10  Wonderful Location, Marvellous Staff, Awesome ...
# 11  Perfect Location, Marvellous Staff, Excellent ...
# 12                   Wonderful Location, Superb Staff
# 13  Wonderful Location, Marvellous Staff, Awesome ...
# 14  Perfect Location, Superb Staff, Awesome Cleanl...
# 15  Wonderful Location, Brilliant Staff, Awesome C...
# 16               Wonderful Location, Marvellous Staff
# 17                     Perfect Location, Superb Staff
# 18  Perfect Location, Superb Staff, Fantastic Clea...
# 19  Perfect Location, Brilliant Staff, Awesome Cle...
# 20  Perfect Location, Superb Staff, Excellent Clea...
# 21               Wonderful Location, Marvellous Staff
# 22  Wonderful Location, Marvellous Staff, Fantasti...
# 23  Wonderful Location, Superb Staff, Fantastic Cl...
# 24                  Wonderful Location, Helpful Staff
# 25
# 26  Wonderful Location, Marvellous Staff, Excellen...
# 27
# 28  Nice Location, Superb Staff, Excellent Cleanli...
# 29
