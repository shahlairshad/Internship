# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
#
# This task will be done in following steps:
#
#     First get the webpage https://www.naukri.com/
#     Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.
#     Then click the search button.
#     Then scrape the data for the first 10 jobs results you get.
#     Finally create a dataframe of the scraped data.

# %%
# import necessary librabies for webscraping with selenium

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#open the naukri page in automated chrome browser

driver.get("https://www.naukri.com/")

# %%
# Enter required designation and location for Data Analyst

#Enter “Data Analyst” in “Skill, Designations, Companies” field

des= driver.find_element(By.XPATH, "/html/body/div[1]/div[6]/div/div/div[1]/div/div/div/input")
des.send_keys("Data Analyst")

# Enter “Bangalore” in “enter the location” field

loc= driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
loc.send_keys("Bangalore")

# %%
#click the search button

search= driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

# %%
# lets make empty list to store data with the given conditions

title= []
location=[]
company=[]
experience=[]

# %%
# Scraping first 10 job title from the given page

title_tags= driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    x= i.text
    title.append(x) 

# Scraping first 10 job location from the given page

loc_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc_tags[0:10]:
    x= i.text
    location.append(x)
    
# Scraping first 10 company name the given page

com_tags= driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in com_tags[0:10]:
    x= i.text
    company.append(x)

# Scraping first 10 experience from the given page

exp_tags=  driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in exp_tags[0:10]:
    x= i.text
    experience.append(x)

# %%
#checking the length

print (len(title), len(location), len(company), len(experience))
# Out:
# 10 10 10 10

# %%
# Creating DataFrame to scrap first 10 data

data_list= list(zip(title, location, company,experience ))

data= pd.DataFrame(data_list, 
    columns =['Job_Title', 'Job_Location', 'Company_Name', 'Experience_Required'],
    index=pd.RangeIndex(start=1, stop=(len(title)+1), name='Sr. No.'))

print ("First 10 Data Analyst jobs data from Naukri is:\n")
data
# Out:
# First 10 Data Analyst jobs data from Naukri is:
#                                                  Job_Title  \
# Sr. No.
# 1                                      Senior Data Analyst
# 2                                             Data Analyst
# 3                                             Data Analyst
# 4                              Data Analyst - CRM Platform
# 5                                             Data Analyst
# 6        Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 7        Call For Clinical Data Analyst - Hyd/Bangalore...
# 8                      Payroll Transformation Data Analyst
# 9                      Payroll Transformation Data Analyst
# 10                 Master Data Management Business Analyst
#
#                                               Job_Location  \
# Sr. No.
# 1                             Bangalore/Bengaluru, Chennai
# 2        Bangalore/Bengaluru, Mangaluru/Mangalore, Pune...
# 3                                      Bangalore/Bengaluru
# 4        Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 5                                      Bangalore/Bengaluru
# 6        Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...
# 7        Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...
# 8                                      Bangalore/Bengaluru
# 9                                      Bangalore/Bengaluru
# 10                                     Bangalore/Bengaluru
#
#                      Company_Name Experience_Required
# Sr. No.
# 1                      Latentview             3-6 Yrs
# 2        Coresight Research, Inc.             4-8 Yrs
# 3                          Varite             2-5 Yrs
# 4               Artech infosystem             1-6 Yrs
# 5                             Jar             0-4 Yrs
# 6                       Cognizant             3-8 Yrs
# 7                       Cognizant             6-9 Yrs
# 8               Arrow Electronics            5-10 Yrs
# 9               Arrow Electronics             3-7 Yrs
# 10                      Accenture             6-8 Yrs

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
# #opening the naukri page in automated chrome browser
driver.get("https://www.naukri.com/")

# %%
#  Lets enter required designation and location for Data Scientist
designation= driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div[1]/input")
location.send_keys('Bangalore')

# %%
# click the search button
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
# lets make empty list to store data with the given conditions

job_title= []
job_location=[]
company_name=[]

# %%
# Scraping first 10 job title from the given page

title_tags= driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    x= i.text
    job_title.append(x)

# %%
# Scraping first 10 job location from the given page

location_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    loc= i.text
    job_location.append(loc)

# %%
# Scraping first 10 company names from the given page

company_tags= driver.find_elements(By.XPATH,'//a[@ class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    x= i.text
    company_name.append(x)

# %%
print(len(job_title), len(job_location), len(company_name))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name})

# %%
df
# Out:
#                                            job_title  \
# 0                            Data Science Specialist
# 1                               Data Science Manager
# 2  Mongodb Database Administrator, Maria DB or Ca...
# 3                   Assistant Manager - Data Science
# 4                                     Data Scientist
# 5                                     Data Scientist
# 6                              Senior Data Scientist
# 7            Data Scientist: Artificial Intelligence
# 8                   Data Scientist - Computer Vision
# 9                              Senior Data Scientist
#
#                                         job_location             company_name
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 2  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...                  Mphasis
# 3                  Bangalore/Bengaluru, Mumbai, Pune               CitiusTech
# 4  Bangalore/Bengaluru, New Delhi, Pune, Gurgaon/...            ZS Associates
# 5  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...            Tech Mahindra
# 6    Bangalore/Bengaluru, Mumbai, New Delhi, Chennai  Boston Consulting Group
# 7                                Bangalore/Bengaluru                      IBM
# 8                                Bangalore/Bengaluru                  Walmart
# 9                 Bangalore/Bengaluru, Pune, Chennai                    Wipro

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below
#
# You have to use the location and salary filter. You have to scrape data for “Data Scientist” designation for first 10 job results. You have to scrape the job-title, job-location, company name, experience required. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakh

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
# Lets enter required designation and location for Data Scientist
designation= driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
# clicking search

search= driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

# %%
# select location filter as “Delhi/NCR”

location_filter = driver.find_element(By.XPATH,'//span[@title="Delhi / NCR"]')
location_filter.click()

# %%
# select salary filter as “3-6” lakhs

salary_filter = driver.find_element(By.XPATH,'//span[@title="3-6 Lakhs"]')
salary_filter.click()

# %%
# lets make empty list to store data with the given conditions

title= []
location=[]
company=[]

# %%
# Scraping first 10 job title from the given page

title_tags= driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    x= i.text
    title.append(x)

# %%
# Scraping first 10 job location from the given page

loc_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc_tags[0:10]:
    x= i.text
    location.append(x)

# %%
# Scraping first 10 company name the given page

com_tags= driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in com_tags[0:10]:
    x= i.text
    company.append(x)

# %%
print(len(title), len(location), len(company))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'job_title':title,'job_location':location,'company_name':company})

# %%
df
# Out:
#                                    job_title  \
# 0                             Data Scientist
# 1            DigitalBCG GAMMA Data Scientist
# 2                             Data Scientist
# 3                             Data Scientist
# 4        Data Scientist / Chat-bot Developer
# 5          Data Scientist - Engine Algorithm
# 6                        Lead Data Scientist
# 7  Data Activation Specialist - Adobe Target
# 8                             Data Scientist
# 9                             Data Scientist
#
#                                         job_location             company_name
# 0                 Noida, Nagpur, Bangalore/Bengaluru              GlobalLogic
# 1                     New Delhi, Bangalore/Bengaluru  Boston Consulting Group
# 2                                   Gurgaon/Gurugram               IHS Markit
# 3                                   Gurgaon/Gurugram                    Optum
# 4  New Delhi, Bangalore/Bengaluru, Mumbai (All Ar...             Big Seo Buzz
# 5  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...             Primo Hiring
# 6         Noida(Sector-59 Noida)\n(WFH during Covid)  R Systems International
# 7  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...           Okda Solutions
# 8                                              Noida             NGI Ventures
# 9  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...     torcai digital media

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#
# 1.Brand
# 2.Product Description
# 3.Price The attributes which you have to scrape is ticked marked in the below image.
# .To scrape the data you have to go through following steps:
#
# 1.Go to Flipkart webpage by url : https://www.flipkart.com/
# 2.Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# 3.After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data as usual
# 4.After scraping data from the first page, go to the “Next” Button at the bottom other page , then click on it.
# 5.Now scrape data from this page as usual
# 6.Repeat this until you get data for 100 sunglasses.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#Go to Flipkart webpage by url : https://www.flipkart.com/

driver.get("https://www.flipkart.com/")

# %%
popup= driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")

popup.click()

# %%
#Lets enter “sunglasses” in the search field where “search for products, brands and more” is written

des= driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

des.send_keys("Sunglasses")

# %%
# click the search icon

search= driver.find_element(By.CLASS_NAME, "_34RNph")
search.click()

# %%
#Scrap the required data 1. Brand, 2. Product Description, 3. Price, 4.Discount

brand_name=[]
product_description=[]
price=[]

# %%
# Scraping first 100 Brand from the given page

# Scraping data from the first page
start=1
end=4
for page in range(start, end):
    brand_tags= driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags:
        x= i.text
        brand_name.append(x)
    
    #Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') 
    next_button.click()
    time.sleep(8)
Top100_brand_name= brand_name[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Scraping first 100 Product Description from the given page

# Scraping data from the first page
start=1
end=4
for page in range(start, end):
    product_tags= driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_tags:
        x= i.text
        product_description.append(x)
    
    #Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
Top100_product_description= product_description[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Scraping first 100 Price from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        x= i.text
        price.append(x)
    
    #Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
Top100_price= price[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
#checking the length

print (len(Top100_brand_name), len(Top100_product_description), len(Top100_price))
# Out:
# 100 100 100

# %%
# Creating DataFrame to scrap first 10 data

data_list= list(zip(Top100_brand_name, Top100_product_description, Top100_price))

data= pd.DataFrame(data_list, 
    columns =['Brand_Name', 'Product Description', 'Price'],
    index=pd.RangeIndex(start=1, stop=101, name='Sr. No.'))

data = data.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("First 100 sunglasses listings on flipkart.com:\n")
data
# Out:
# First 100 sunglasses listings on flipkart.com:
# <style type="text/css">
# #T_b2bb4_row0_col0, #T_b2bb4_row0_col1, #T_b2bb4_row0_col2, #T_b2bb4_row1_col0, #T_b2bb4_row1_col1, #T_b2bb4_row1_col2, #T_b2bb4_row2_col0, #T_b2bb4_row2_col1, #T_b2bb4_row2_col2, #T_b2bb4_row3_col0, #T_b2bb4_row3_col1, #T_b2bb4_row3_col2, #T_b2bb4_row4_col0, #T_b2bb4_row4_col1, #T_b2bb4_row4_col2, #T_b2bb4_row5_col0, #T_b2bb4_row5_col1, #T_b2bb4_row5_col2, #T_b2bb4_row6_col0, #T_b2bb4_row6_col1, #T_b2bb4_row6_col2, #T_b2bb4_row7_col0, #T_b2bb4_row7_col1, #T_b2bb4_row7_col2, #T_b2bb4_row8_col0, #T_b2bb4_row8_col1, #T_b2bb4_row8_col2, #T_b2bb4_row9_col0, #T_b2bb4_row9_col1, #T
_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b2bb4_row3_col0" class="data row3 col0" >NuV

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. This task will be done in following steps:
#
# First get the webpage https://www.flipkart.com/
# Enter “iphone 11” in “Search” field .
# Then click the search button. You will reach to the below shown webpage . As shown in the above page you have to scrape the tick marked attributes.These are:
# Rating
# Review summary
# Full review
# You have to scrape this data for first 100 reviews.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Lets first connect to the driver

#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#Go to Flipkart webpage by url : https://www.flipkart.com/

driver.get("https://www.flipkart.com/")

# %%
# close the popup window

popup_close = driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
popup_close.click()

# %%
# lets Enter “iphone 11” in “Search” field

des= driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
des.send_keys("iphone 11")

# %%
#click on search 

search= driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search.click()

# %%
#click the first results from all iphone 11 data

click_first = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[2]')
click_first.click()

# %%
# as the result open up in new tab of the browser we need to go that tab

driver.switch_to.window(driver.window_handles[1])

# %%
#clicking on the all reviews button

all_rev = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[7]/div/a/div/span')
all_rev.click()

# %%
#Scrap the required data Rating, Review summary, Full review

ratings=[]
review_summary=[]
full_review=[]

# %%
# Scraping first 100 Ratings the given page

start = 0 #starting page
end = 10 # page number to end scaping


for page in range(start,end):
    
    #scrape the ratings
    
    rating_tags = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tags:
        x= i.text
        ratings.append(x)
        
    #getting the nextpage button & clicking next 
    
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)

# %%
len(ratings)
# Out:
# 100

# %%
# Scraping first 100 Review summary the given page

start = 0 #starting page
end = 10 # page number to end scaping


for page in range(start,end):
    
    # scrape the review summaries
    
    review_sum_tags = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in review_sum_tags:
        x= i.text
        review_summary.append(x)    
    
    #getting the nextpage button & clicking next 
    
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)

# %%
len(review_summary)
# Out:
# 100

# %%
# Scraping first 100 full review the given page

start = 0 #starting page
end = 10 # page number to end scraping


for page in range(start,end):
    
    # scrape the full reviews
    
    full_review_tags = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full_review_tags:
        x= i.text
        full_review.append(x.replace("\n"," "))
        
    #getting the nextpage button & clicking next 
    
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)

# %%
len(full_review)
# Out:
# 100

# %%
# Creating DataFrame to scrap first 10 data

data_list= list(zip(ratings, review_summary, full_review))

data= pd.DataFrame(data_list,
    columns =['Ratings', 'Review Summary', 'Full Summary'],
    index=pd.RangeIndex(start=1, stop=101, name='Sr. No.'))

data = data.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("First 100 reviews data from flipkart.com for iphone11 phone:\n")
data
# Out:
# First 100 reviews data from flipkart.com for iphone11 phone:
# <style type="text/css">
# #T_74ca0_row0_col0, #T_74ca0_row0_col1, #T_74ca0_row0_col2, #T_74ca0_row1_col0, #T_74ca0_row1_col1, #T_74ca0_row1_col2, #T_74ca0_row2_col0, #T_74ca0_row2_col1, #T_74ca0_row2_col2, #T_74ca0_row3_col0, #T_74ca0_row3_col1, #T_74ca0_row3_col2, #T_74ca0_row4_col0, #T_74ca0_row4_col1, #T_74ca0_row4_col2, #T_74ca0_row5_col0, #T_74ca0_row5_col1, #T_74ca0_row5_col2, #T_74ca0_row6_col0, #T_74ca0_row6_col1, #T_74ca0_row6_col2, #T_74ca0_row7_col0, #T_74ca0_row7_col1, #T_74ca0_row7_col2, #T_74ca0_row8_col0, #T_74ca0_row8_col1, #T_74ca0_row8_col2, #T_74ca0_row9_col0, #T_74ca0_row9_col1, #T_74ca0_row9_col2, #T_74ca0_row10_col0, #T_74ca0_row10_col1, #T_74ca0_row10_col2, #T_74ca0_row11_col0, #T_74ca0_row11_col1, #T_74ca0_row11_col2, #T_74ca0_row12_col0, #T_74ca0_row12_col1, #T_74ca0_row12_col2, #T_74ca0_row13_col0, #T_74ca0_row13_col1, #T_74ca0_row13_col2, #T_74ca0_row14_col0, #T_74ca0_row14_col1, #T_74ca0_row14_col2, #T_74ca0_row15_col0, #T_74ca0_row15_col1, #T_74ca0_row15_col2, #T_74ca0_row16_col0, #T_74ca0_row16_col1, #T_74ca0_row16_col2, #T_74ca0_row17_col0, #T_74ca0_row17_col1, #T_74ca0_row17_col2, #T_74ca0_row18_col0, #T_74ca0_row18_col1, #T_74ca0_row18_col2, #T_74ca0_row19_col0, #T_74ca0_row19_col1, #T_74ca0_row19_col2, #T_74ca0_row20_col0, #T_74ca0_row20_col1, #T_74ca0_row20_col2, #T_74ca0_row21_col0, #T_74ca0_row21_col1, #T_74ca0_row21_col2, #T_74ca0_row22_col0, #T_74ca0_row22_col1, #T_74ca0_row22_col2, #T_74ca0_row23_col0, #T_74ca0_row23_col1, #T_74ca0_row23_col2, #T_74ca0_row24_col0, #T_74ca0_row24_col1, #T_74ca0_row24_col2, #T_74ca0_row25_col0, #T_74ca0_row25_col1, #T_74ca0_row25_col2, #T_74ca0_row26_col0, #T_74ca0_row26_col1, #T_74ca0_row26_col2, #T_74ca0_row27_col0, #T_74ca0_row27_col1, #T_74ca0_row27_col2, #T_74ca0_row28_col0, #T_74ca0_row28_col1, #T_74ca0_row28_col2, #T_74ca0_row29_col0, #T_74ca0_row29_col1, #T_74ca0_row29_col2, #T_74ca0_row30_col0, #T_74ca0_row30_col1, #T_74ca0_row30_col2, #T_74ca0_row31_col0, #T_74ca0_row31_col1, #T_74ca0_row31_col2, #T_74ca0_row32_col0, #T_74ca0_row32_col1, #T_74ca0_row32_col2, #T_74ca0_row33_col0, #T_74ca0_row33_col1, #T_74ca0_row33_col2, #T_74ca0_row34_col0, #T_74ca0_row34_col1, #T_74ca0_row34_col2, #T_74ca0_row35_col0, #T_74ca0_row35_col1, #T_74ca0_row35_col2, #T_74ca0_row36_col0, #T_74ca0_row36_col1, #T_74ca0_row36_col2, #T_74ca0_row37_col0, #T_74ca0_row37_col1, #T_74ca0_row37_col2, #T_74ca0_row38_col0, #T_74ca0_row38_col1, #T_74ca0_row38_col2, #T_74ca0_row39_col0, #T_74ca0_row39_col1, #T_74ca0_row39_col2, #T_74ca0_row40_col0, #T_74ca0_row40_col1, #T_74ca0_row40_col2, #T_74ca0_row41_col0, #T_74ca0_row41_col1, #T_74ca0_row41_col2, #T_74ca0_row42_col0, #T_74ca0_row42_col1, #T_74ca0_row42_col2, #T_74ca0_row43_col0, #T_74ca0_row43_col1, #T_74ca0_row43_col2, #T_74ca0_row44_col0, #T_74ca0_row44_col1, #T_74ca0_row44_col2, #T_74ca0_row45_col0, #T_74ca0_row45_col1, #T_74ca0_row45_col2, #T_74ca0_row46_col0, #T_74ca0_row46_col1, #T_74ca0_row46_col2, #T_74ca0_row47_col0, #T_74ca0_row47_col1, #T_74ca0_row47_col2, #T_74ca0_row48_col0, #T_74ca0_row48_col1, #T_74ca0_row48_col2, #T_74ca0_row49_col0, #T_74ca0_row49_col1, #T_74ca0_row49_col2, #T_74ca0_row50_col0, #T_74ca0_row50_col1, #T_74ca0_row50_col2, #T_74ca0_row51_col0, #T_74ca0_row51_col1, #T_74ca0_row51_col2, #T_74ca0_row52_col0, #T_74ca0_row52_col1, #T_74ca0_row52_col2, #T_74ca0_row53_col0, #T_74ca0_row53_col1, #T_74ca0_row53_col2, #T_74ca0_row54_col0, #T_74ca0_row54_col1, #T_74ca0_row54_col2, #T_74ca0_row55_col0, #T_74ca0_row55_col1, #T_74ca0_row55_col2, #T_74ca0_row56_col0, #T_74ca0_row56_col1, #T_74ca0_row56_col2, #T_74ca0_row57_col0, #T_74ca0_row57_col1, #T_74ca0_row57_col2, #T_74ca0_row58_col0, #T_74ca0_row58_col1, #T_74ca0_row58_col2, #T_74ca0_row59_col0, #T_74ca0_row59_col1, #T_74ca0_row59_col2, #T_74ca0_row60_col0, #T_74ca0_row60_col1, #T_74ca0_row60_col2, #T_74ca0_row61_col0, #T_74ca0_row61_col1, #T_74ca0_row61_col2, #T_74ca0_row62_col0, #T_74ca0_row62_col1, #T_74ca0_row62_col2, #T_74ca0_row63_col0, #T_74ca0_row63_col1, #T_74ca0_row63_col2 ...
#   text-align: right;
# }
# </style>
# <table id="T_74ca0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Ratings</th>
#       <th class="col_heading level0 col1" >Review Summary</th>
#       <th class="col_heading level0 col2" >Full Summary</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sr. No.</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74ca0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_74ca0_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_74ca0_row0_col1" class="data row0 col1" >Simply awesome</td>
#       <td id="T_74ca0_row0_col2" class="data row0 col2" >Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.</td>
#     </tr>
#     <tr>
#       <th id="T_74ca0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_74ca0_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_74ca0_row1_col1" class="data row1 col1" >Value-for-money</td>
#       <td id="T_74ca0_row1_col2" class="data row1 col2" >I'm Really happy with the product Delivery was fast as well ..it was a gift for my sister and she loved it so much.</td>
#     </tr>
#     <tr>
#       <th id="T_74ca0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_74ca0_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_74ca0_row2_col1" class="data row2 col1" >Perfect product!</td>
#       <td id="T_74ca0_row2_col2" class="data row2 col2" >Amazing phone with great cameras and b

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field. You have to scrape 4 attributes of each sneaker:
#
# 1. Brand
# 2. Product Description
# 3. Price As shown in the below image, you have to scrape the tick marked attributes

# %%
#Lets first connect to the driver

#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#Go to Flipkart webpage by url : https://www.flipkart.com/

driver.get("https://www.flipkart.com/")

# %%
# close the popup window

popup= driver.find_element(By.XPATH, "/html/body/div[2]/div/div/button")
popup.click()

# %%
# lets Enter “iphone 11” in “Search” field

des= driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

des.send_keys("sneakers")

# %%
#click on search button

search= driver.find_element(By.CLASS_NAME, "L0Z3Pu")
search.click()

# %%
#Scrap the required data Brand, Product Description, Price, Discount (as shown in the given picture)

brand_name=[]
product_description=[]
price=[]
discount=[]

# %%
# Scraping first 100 Brand from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    brand_tags= driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags:
        x= i.text
        brand_name.append(x)
    
    # Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)
Top100_brand_name= brand_name[0:100] #Top 100 data

# %%
len(brand_name)
# Out:
# 120

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Scraping first 100 Product Description from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    product_tags= driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_tags:
        x= i.text
        product_description.append(x)
        
    
    # Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
Top100_product_description= product_description[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Scraping first 100 Price from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        x= i.text
        price.append(x)
        
    # Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') #Go to the “Next” Button at the bottom other page and scrap data
    next_button.click()
    time.sleep(3)
Top100_price= price[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Scraping first 100 Discount from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in price_tags:
        x= i.text
        discount.append(x) 
        
    # Go to the “Next” Button at the bottom other page and scrap data
     
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') #Go to the “Next” Button at the bottom other page and scrap data
    next_button.click()
    time.sleep(3)
Top100_discount = discount[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Creating DataFrame of first 100 scrapped data

list_data= list(zip(Top100_brand_name, Top100_product_description, Top100_price, Top100_discount))

data= pd.DataFrame( list_data,
        index=pd.RangeIndex(start=1, stop=101, name='Sr. No.'),
        columns =['Brand_Name','Product Description', 'Price', 'Discount'])

data = data.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("First 100 sneakers data from Flipkart is:\n")
data
# Out:
# First 100 sneakers data from Flipkart is:
# <style type="text/css">
# #T_923c6_row0_col0, #T_923c6_row0_col1, #T_923c6_row0_col2, #T_923c6_row0_col3, #T_923c6_row1_col0, #T_923c6_row1_col1, #T_923c6_row1_col2, #T_923c6_row1_col3, #T_923c6_row2_col0, #T_923c6_row2_col1, #T_923c6_row2_col2, #T_923c6_row2_col3, #T_923c6_row3_col0, #T_923c6_row3_col1, #T_923c6_row3_col2, #T_923c6_row3_col3, #T_923c6_row4_col0, #T_923c6_row4_col1, #T_923c6_row4_col2, #T_923c6_row4_col3, #T_923c6_row5_col0, #T_923c6_row5_col1, #T_923c6_row5_col2, #T_923c6_row5_col3, #T_923c6_row6_col0, #T_923c6_row6_col1, #T_923c6_row6_col2, #T_923c6_row6_col3, #T_923c6_row7_col0, #T_923c6_row7_col1, #T_923c6_row7_col2, #T_923c
T_923c6_row37_col0, #T_923c6_row37_col1, #T_923c6_row37_col2, #T_923c6_row37_col3, #T_923c6_row38_col0, #T_923c6_row38_col1, #T_923c6_row38_col2, #T_923c6_row38_col3, #T_923c6_row39_col0, #T_923c6_row39_col1, #T_923c6_row39_col2, #T_923c6_row39_col3, #T_923c6_row40_col0, #T_923c6_row40_col1, #T_923c6_row40_col2, #T_923c6_row40_col3, #T_923c6_row41_col0, #T_923c6_row41_col1, #T_923c6_row41_col2, #T_923c6_row41_col3, #T_923c6_row42_col0, #T_923c6_row42_col1, #T_923c6_row42_col2, #T_923c6_row42_col3, #T_923c6_row43_col0, #T_923c6_row43_col1, #T_923c6_row43_col2, #T_923c6_row43_col3, #T_923c6_row44_col0, #T_923c6_row44_col1, #T_923c6_row44_col2, #T_923c6_row44_col3, #T_923c6_row45_col0, #T_923c6_row45_col1, #T_923c6_row45_col2, #T_923c6_row45_col3, #T_923c6_row46_col0, #T_923c6_row46_col1, #T_923c6_row46_col2, #T_923c6_row46_col3, #T_923c6_row47_col0, #T_923c6_row47_col1, #T_923c6_row47_col2, #T_923c6_row47_col3, #T_923c6 ...

# %% [markdown]
# Q7: Go to the link - https://www.myntra.com/shoes Set second Price filter and Color filter to “Black”, as shown in the below image.
#
# And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe description, price of the shoe as shown in the below image.

# %%
#Lets first connect to the driver

#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#Go to Flipkart webpage by url: https://www.myntra.com/shoes

driver.get(" https://www.myntra.com/shoes")

# %%
#apply second price filter 

price_filter = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label')
price_filter.click()

# %%
#apply Color filter to “Black”

color_filter = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label')
color_filter.click()

# %%
#Scrap the required data Brand, Product Description, Price

brand_name=[]
product_description=[]
price=[]

# %%
# Scraping first 100 Brand from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    brand_tags= driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
    for i in brand_tags:
        x= i.text
        brand_name.append(x)
        
    # Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//li[@class="pagination-next"]') #Go to the “Next” Button at the bottom other page and scrap data
    next_button.click()
    time.sleep(3)
Top100_brand_name= brand_name[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[3]/a')
prev_button.click()

# %%
# Scraping first 100 Product Description from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    product_tags= driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
    for i in product_tags:
        x= i.text
        product_description.append(x)
        
    # Go to the “Next” Button at the bottom other page and scrap data
        
    next_button= driver.find_element(By.XPATH,'//li[@class="pagination-next"]')
    next_button.click()
    time.sleep(3)
Top100_product_description= product_description[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[3]/a')
prev_button.click()

# %%
# Scraping first 100 Price from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="product-price"]')
    for i in price_tags:
        x= i.text
        price.append(x)
        
    # Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//li[@class="pagination-next"]') #Go to the “Next” Button at the bottom other page and scrap data
    next_button.click()
    time.sleep(3)
Top100_price= price[0:100] #Top 100 data

# %%
print(len(Top100_brand_name), len(Top100_product_description), len(Top100_price))
# Out:
# 100 100 100

# %%
# Creating DataFrame of first 100 scrapped data

list_data= list(zip(Top100_brand_name, Top100_product_description, Top100_price))

data= pd.DataFrame( list_data,
        index=pd.RangeIndex(start=1, stop=101, name='Sr. No.'),
        columns =['Brand_Name','Product Description', 'Price'])

data = data.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("First 100 sneakers data from Flipkart is:\n")
data
# Out:
# First 100 sneakers data from Flipkart is:
# <style type="text/css">
# #T_e8d41_row0_col0, #T_e8d41_row0_col1, #T_e8d41_row0_col2, #T_e8d41_row1_col0, #T_e8d41_row1_col1, #T_e8d41_row1_col2, #T_e8d41_row2_col0, #T_e8d41_row2_col1, #T_e8d41_row2_col2, #T_e8d41_row3_col0, #T_e8d41_row3_col1, #T_e8d41_row3_col2, #T_e8d41_row4_col0, #T_e8d41_row4_col1, #T_e8d41_row4_col2, #T_e8d41_row5_col0, #T_e8d41_row5_col1, #T_e8d41_row5_col2, #T_e8d41_row6_col0, #T_e8d41_row6_col1, #T_e8d41_row6_col2, #T_e8d41_row7_col0, #T_e8d41_row7_col1, #T_e8d41_row7_col2, #T_e8d41_row8_col0, #T_e8d41_row8_col1, #T_e8d41_row8_col2, #T_e8d41_row9_col0, #T_e8d41_row9_col1, #T_e8d41_row9_col2, #T_e8d41_row10_col0, #T_e8d41_row10_col1, #T_e8d41_row10_col2, #T_e8d41_row11_col0, #T_e8d41_row11_col1, #T_e8d41_row11_col2, #T_e8d41_row12_col0, #T_e8d41_row12_col1, #T_e8d41_row12_col2, #T_e8d41_row13_col0, #T_e8d41_row13_col1, #T_e8d41_row13_col2, #T_e8d41_row14_col0, #T_e8d41_row14_col1, #T_e8d41_row14_col2, #T_e8d41_row15_col0, #T_e8d41_row15_col1, #T_e8d41_row15_col2, #T_e8d41_row16_col0, #T_e8d41_row16_col1, #T_e8d41_row16_col2, #T_e8d41_row17_col0, #T_e8d41_row17_col1, #T_e8d41_row17_col2, #T_e8d41_row18_col0, #T_e8d41_row18_col1, #T_e8d41_row18_col2, #T_e8d41_row19_col0, #T_e8d41_row19_col1, #T_e8d41_row19_col2, #T_e8d41_row20_col0, #T_e8d41_row20_col1, #T_e8d41_row20_col2, #T_e8d41_row21_col0, #T_e8d41_row21_col1, #T_e8d41_row21_col2, #T_e8d41_row22_col0, #T_e8d41_row22_col1, #T_e8d41_row22_col2, #T_e8d41_row23_col0, #T_e8d41_row23_col1, #T_e8d41_row23_col2, #T_e8d41_row24_col0, #T_e8d41_row24_col1, #T_e8d41_row24_col2, #T_e8d41_row25_col0, #T_e8d41_row25_col1, #T_e8d41_row25_col2, #T_e8d
">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Brand_Name</th>
#       <th class="col_heading level0 col1" >Product Description</th>
#       <th class="col_heading level0 col2" >Price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sr. No.</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8d41_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e8d41_row0_col0" class="data row0 col0" >UNDER ARMOUR</td>
#       <td id="T_e8d41_row0_col1" class="data row0 col1" >Men HOVR SonicSE Running Shoes</td>
#       <td id="T_e8d41_row0_col2" class="data row0 col2" >Rs. 8499Rs. 9999(15% OFF)</td>
#     </tr>
#     <tr>
#       <th id="T_e8d41_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e8d41_row1_col0" class="data row1 col0" >UNDER ARMOUR</td>
#       <td id="T_e8d41_row1_col1" class="data row1 col1" >Men ChargedEscape 3 BL Running</td>
#       <td id="T_e8d41_row1_col2" class="data row1 col2" >Rs. 7199Rs. 8999(20% OFF)</td>
#     </tr>
#     <tr>
#       <th id="T_e8d41_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e8d41_row2_col0" class="data row2 col0" >UNDER ARMOUR</td>
#       <td id="T_e8d41_row2_col1" class="data row2 col1" >Unisex 3ZER0 IV Basketball</td>
#       <td id="T_e8d41_row2_col2" class="data row2 col2" >Rs. 7649Rs. 8999(15% OFF)</td>
#     </tr>
#     <tr>
#       <th id="T_e8d41_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e8d41_row3_col0" class="data row3 c

# %% [markdown]
# 8: Go to webpage https://www.amazon.in/. Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” as shown in the below image:
#
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributesfor each laptop:
#
#    1. Title
#    2.Ratings
#    3. Price

# %%
#Lets first connect to the driver

#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#Go to Flipkart webpage by url: https://www.amazon.in/

driver.get("https://www.amazon.in/")

# %%
# Lets enter Laptop in the search field and then click the search icon.

des= driver.find_element(By.XPATH, "/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
des.send_keys("Laptop")

# %%
# click the search button

search= driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
# select cpu filter

cpu_filter_i7 = driver.find_element(By.XPATH,'//li[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span/a/span')
cpu_filter_i7.click()

# %%
#Scrap the required data

title=[]
ratings=[]
price=[]

# %%
#title of the laptops

#title_tags= driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
title_tags = driver.find_elements(By.XPATH,"//span[@class='a-size-medium a-color-base a-text-normal']")
for i in title_tags[0:10]:
    x= i.text
    title.append(x)

# %%
#ratings 
rating_tags=driver.find_elements(By.XPATH,"//a[@class='a-popover-trigger a-declarative']")

for i in rating_tags[0:10]:
    if i.text is None:
        ratings.append("--")
    else:
        ratings.append(i.get_attribute("text"))

# %%
#prices of the laptops

price_tags=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in price_tags[0:10]:
    x= i.text
    price.append(x)

# %%
# Creating DataFrame of first 10 scrapped data

list_data= list(zip(title, ratings, price))

data= pd.DataFrame( list_data,
        index=pd.RangeIndex(start=1, stop=11, name='Sr. No.'),
        columns =['Title_of_Laptop', 'Ratings', 'Price'])

data = data.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("First 10 laptop's data from Amazon is:\n\n")
data
# Out:
# First 10 laptop's data from Amazon is:
# <style type="text/css">
# #T_4d3f3_row0_col0, #T_4d3f3_row0_col1, #T_4d3f3_row0_col2, #T_4d3f3_row1_col0, #T_4d3f3_row1_col1, #T_4d3f3_row1_col2, #T_4d3f3_row2_col0, #T_4d3f3_row2_col1, #T_4d3f3_row2_col2, #T_4d3f3_row3_col0, #T_4d3f3_row3_col1, #T_4d3f3_row3_col2, #T_4d3f3_row4_col0, #T_4d3f3_row4_col1, #T_4d3f3_row4_col2, #T_4d3f3_row5_col0, #T_4d3f3_row5_col1, #T_4d3f3_row5_col2, #T_4d3f3_row6_col0, #T_4d3f3_row6_col1, #T_4d3f3_row6_col2, #T_4d3f3_row7_col0, #T_4d3f3_row7_col1, #T_4d3f3_row7_col2, #T_4d3f3_row8_col0, #T_4d3f3_row8_col1, #T_4d3f3_row8_col2, #T_4d3f3_row9_col0, #T_4d3f3_row9_col1, #T_4d3f3_row9_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_4d3f3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Title_of_Laptop</th>
#       <th class="col_heading level0 col1" >Ratings</th>
#       <th class="col_heading level0 col2" >Price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sr. No.</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d3f3_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4d3f3_row0_col0" class="data row0 col0" >Fujitsu UH-X 11th Gen Intel Core i7 13.3" FHD IPS 400Nits 2-in1 Touch Convertible Laptop (16GB/1TB SSD/Windows 11/MS Office 2021/Iris Xe Graphics/2 Yr Warranty/Backlit Kb/Black/0.997 kg, 4ZR1F38027)</td>
#       <td id="T_4d3f3_row0_col1" class="data row0 col1" >4.2 out of 5 stars</td>
#       <td id="T_4d3f3_row0_col2" class="data row0 col2" >1,00,000</td>
#     </tr>
#     <tr>
#       <th id="T_4d3f3_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4d3f3_row1_col0" class="data row1 col0" >Acer Spin 5 Professional Laptop (12th Gen Intel Core i7/16GB RAM/1 TB SSD) SP514-51N, 1.3 KG</td>
#       <td id="T_4d3f3_row1_col1" class="data row1 col1" >4.3 out of 5 stars</td>
#       <td id="T_4d3f3_row1_col2" class="data row1 col2" >1,24,990</td>
#     </tr>
#     <tr>
#       <th id="T_4d3f3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4d3f3_row2_col0" class="data row2 col0" >ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FHD OLED, Intel EVO Core i7-1165G7 11th Gen, Thin and Light Laptop (16GB/1TB SSD/Iris Xe Graphics/Windows 11/Office 2021/Mist/1.14 kg), UX325EA-KG701WS</td>
#       <td id="T_4d3f3_row2_col1" class="data row2 col1" >3.7 out of 5 stars</td>
#       <td id="T_4d3f3_row2_col2" class="data row2 col2" >93,290</td>
#     </tr>
#     <tr>
#       <th id="T_4d3f3_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4d3f3_row3_col0" class="data row3 col0" >ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, Intel Core i7-1065G7 10th Gen, Thin and Light Laptop (16GB/512GB SSD/Iris Plus Graphics/Windows 11/Office 2021/Silver/1.8 kg), X515JA-EJ701WS</td>
#       <td id="T_4d3f3_row3_col1" class="data row3 col1" >4.5 out of 5 stars</td>
#       <td id="T_4d3f3_row3_col2" class="data row3 col2" >77,990</td>
#     </tr>
#     <tr>
#       <th id="T_4d3f3_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_4d3f3_row4_col0" class="data row4 col0" >Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN</td>
#       <td id="T_4d3f3_row4_col1" class="data row4 col1" >4.3 out of 5 stars</td>
#       <td id="T_4d3f3_row4_col2" class="data row4 col2" >79,990</td>
#     </tr>
#     <tr>
#       <th id="T_4d3f3_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_4d3f3_row5_col0" class="data row5 col0" >Lenovo ThinkBook 15 Intel 11th Gen Core i7 15.6"(39.62 cm)FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11 Home/MS Office H&S 2021/Iris® Xe Graphics/Backlit/Mineral Grey/1.7 Kg) 20VE00W4IH</td>
#       <td id="T_4d3f3_row5_col1" class="data row5 col1" >4.2 out of 5 stars</td>
#       <td id="T_4d3f3_row5_col2" class="data row5 col2" >77,990</td>
#     </tr>
#     <tr>
#       <th id="T_4d3f3_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_4d3f3_row6_col0" class="data row6 col0" >HP Pavilion Plus, 12th Gen Intel Core i7 16GB RAM/1TB SSD 14 inch(35.6 cm),OLED,400 nits,UWVA, Eye Safe Laptop/Intel Iris Xe Graphics/Backlit KB/B&O/FPR/Win 11/Alexa Built-in/MSO 2021, 14-eh0024TU</td>
#       <td id="T_4d3f3_row6_col1" class="data row6 col1" >4.2 out of 5 stars</td>
#       <td id="T_4d3f3_row6_col2" class="data row6 col2" >86,990</td>
#     </tr>
#     <tr>
#       <th id="T_4d3f3_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_4d3f3_row7_col0" class="data row7 col0" >HP Pavilion x360 11th Gen Intel Core i7 14 inch(35.6 cm) FHD,IPS, Multitouch 2-in-1 Laptop(16GB RAM/512GB SSD/Backlit KB/Intel Iris Xe Graphics/Pen/Alexa Built-in/MSO/1.52Kg) 14-dy1050TU, Spruce Blue</td>
#       <td id="T_4d3f3_row7_col1" class="data row7 col1" >4.4 out of 5 stars</td>
#       <td id="T_4d3f3_row7_col2" class="data row7 col2" >80,990</td>
#     </tr>
#     <tr>
#       <th id="T_4d3f3_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_4d3f3_row8_col0" class="data row8 col0" >Lenovo Yoga 7i 11th Gen Intel Core i7-1165G7 14 inches FHD IPS 2-in-1 Touchscreen Business Laptop (16GB/512GB SSD/Windows 10/MS Office/Digital Pen/Fingerprint Reader/Slate Grey/1.43Kg), 82BH004HIN</td>
#       <td id="T_4d3f3_row8_col1" class="data row8 col1" >2.9 out of 5 stars</td>
#       <td id="T_4d3f3_row8_col2" class="data row8 col2" >1,11,000</td>
#     </tr>
#     <tr>
#       <th id="T_4d3f3_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_4d3f3_row9_col0" class="data row9 col0" >Lenovo IdeaPad Gaming 3 Intel Core i7-12700H 16"(40.64cm) WUXGA IPS 165Hz Gaming Laptop (16GB/512GB SSD/Win 11/Office 2021/NVIDIA RTX 3060 6GB/Alexa/3 Month Game Pass/Onyx Grey/2.6Kg),82SA00B2IN</td>
#       <td id="T_4d3f3_row9_col1" class="data row9 col1" >4.2 out of 5 stars</td>
#       <td id="T_4d3f3_row9_col2" class="data row9 col2" >1,09,990</td>
#     </tr>
#   </tbody>
# </table>
