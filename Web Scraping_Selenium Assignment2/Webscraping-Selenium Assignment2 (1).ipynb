# %% [markdown]
# # WEB SCRAPING – ASSIGNMENT 2

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\sahal\anaconda3\lib\site-packages (4.4.3)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\sahal\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\sahal\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\sahal\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio~=0.17 in c:\users\sahal\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: outcome in c:\users\sahal\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\sahal\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\sahal\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: async-generator>=1.9 in c:\users\sahal\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\sahal\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: sortedcontainers in c:\users\sahal\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sahal\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: pycparser in c:\users\sahal\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\sahal\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sahal\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\sahal\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
# Enter required designation and location for Data Analyst

designation= driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
# lets make empty list to store data with the given conditions

job_title= []
job_location=[]
company_name=[]
experience_required=[]

# %%
# Scraping first 10 job title from the given page

title_tags= driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    x= i.text
    job_title.append(x)

# %%
# Scraping first 10 job location from the given page

location_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    loc= i.text
    job_location.append(loc)

# %%
company_tags= driver.find_elements(By.XPATH,'//a[@ class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    x= i.text
    company_name.append(x)

# %%
experience_tags= driver.find_elements(By.XPATH, '//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in experience_tags[0:10]:
    x= i.text
    experience_required.append(x)

# %%
print(len(job_title), len(job_location), len(company_name), len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'job_title':job_title,'job_location':location,'company_name':company_name,'experience_required':experience_required})

# %%
df
# Out:
#                                            job_title  \
# 0                                Senior Data Analyst
# 1                                       Data Analyst
# 2  Hiring For Data Analyst (DA)/ Team Lead (TL) -...
# 3  Call For Clinical Data Analyst - Hyd/Bangalore...
# 4                Payroll Transformation Data Analyst
# 5                                    HR Data Analyst
# 6                                Senior Data Analyst
# 7                          Sr. SAP Hana Data Analyst
# 8    Business Execution (Data and Reporting Analyst)
# 9                                       Data Analyst
#
#                                         job_location  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  <selenium.webdriver.remote.webelement.WebEleme...
# 3  <selenium.webdriver.remote.webelement.WebEleme...
# 4  <selenium.webdriver.remote.webelement.WebEleme...
# 5  <selenium.webdriver.remote.webelement.WebEleme...
# 6  <selenium.webdriver.remote.webelement.WebEleme...
# 7  <selenium.webdriver.remote.webelement.WebEleme...
# 8  <selenium.webdriver.remote.webelement.WebEleme...
# 9  <selenium.webdriver.remote.webelement.WebEleme...
#
#                company_name experience_required
# 0                Latentview             3-6 Yrs
# 1                       Jar             0-4 Yrs
# 2                 Cognizant             3-8 Yrs
# 3                 Cognizant             6-9 Yrs
# 4         Arrow Electronics             3-7 Yrs
# 5              Hitachi Ltd.             3-6 Yrs
# 6                      Klub             2-5 Yrs
# 7                  Anicalls            5-10 Yrs
# 8               Wells Fargo            6-11 Yrs
# 9  Coresight Research, Inc.             4-8 Yrs

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
# #opening the naukri page in automated chrome browser
driver.get("https://www.naukri.com/")

# %%
#  Lets enter required designation and location for Data Scientist
designation= driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
# click the search button
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
# lets make empty list to store data with the given conditions

job_title= []
job_location=[]
company_name=[]

# %%
# Scraping first 10 job title from the given page

title_tags= driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    x= i.text
    job_title.append(x)

# %%
# Scraping first 10 job location from the given page

location_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    loc= i.text
    job_location.append(loc)

# %%
# Scraping first 10 company names from the given page

company_tags= driver.find_elements(By.XPATH,'//a[@ class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    x= i.text
    company_name.append(x)

# %%
print(len(job_title), len(job_location), len(company_name))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'job_title':job_title,'job_location':location,'company_name':company_name})
df
# Out:
#                                            job_title  \
# 0                            Data Science Specialist
# 1                               Data Science Manager
# 2  Mongodb Database Administrator, Maria DB or Ca...
# 3                   Analystics & Modeling Specialist
# 4                   Assistant Manager - Data Science
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                              Senior Data Scientist
# 8            Data Scientist: Artificial Intelligence
# 9                   Data Scientist - Computer Vision
#
#                                         job_location             company_name
# 0  <selenium.webdriver.remote.webelement.WebEleme...                Accenture
# 1  <selenium.webdriver.remote.webelement.WebEleme...                Accenture
# 2  <selenium.webdriver.remote.webelement.WebEleme...                  Mphasis
# 3  <selenium.webdriver.remote.webelement.WebEleme...                Accenture
# 4  <selenium.webdriver.remote.webelement.WebEleme...               CitiusTech
# 5  <selenium.webdriver.remote.webelement.WebEleme...            ZS Associates
# 6  <selenium.webdriver.remote.webelement.WebEleme...            Tech Mahindra
# 7  <selenium.webdriver.remote.webelement.WebEleme...  Boston Consulting Group
# 8  <selenium.webdriver.remote.webelement.WebEleme...                      IBM
# 9  <selenium.webdriver.remote.webelement.WebEleme...                  Walmart

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below
#
# You have to use the location and salary filter. You have to scrape data for “Data Scientist” designation for first 10 job results. You have to scrape the job-title, job-location, company name, experience required. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakh

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
# Lets enter required designation and location for Data Scientist
designation= driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
# clicking search

search= driver.find_element(By.CLASS_NAME, "qsbSubmit")
search.click()

# %%
# select location filter as “Delhi/NCR”

location_filter = driver.find_element(By.XPATH,'//span[@title="Delhi / NCR"]')
location_filter.click()

# %%
# select salary filter as “3-6” lakhs

salary_filter = driver.find_element(By.XPATH,'//span[@title="3-6 Lakhs"]')
salary_filter.click()

# %%
# lets make empty list to store data with the given conditions

title= []
location=[]
company=[]

# %%
# Scraping first 10 job title from the given page

title_tags= driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    x= i.text
    title.append(x)

# %%
# Scraping first 10 job location from the given page

loc_tags= driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc_tags[0:10]:
    x= i.text
    location.append(x)

# %%
# Scraping first 10 company name the given page

com_tags= driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in com_tags[0:10]:
    x= i.text
    company.append(x)

# %%
print(len(title), len(location), len(company))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'job_title':title,'job_location':location,'company_name':company})
df
# Out:
#                                    job_title  \
# 0                             Data Scientist
# 1            DigitalBCG GAMMA Data Scientist
# 2                             Data Scientist
# 3                        Lead Data Scientist
# 4                             Data Scientist
# 5        Data Scientist / Chat-bot Developer
# 6          Data Scientist - Engine Algorithm
# 7  Data Activation Specialist - Adobe Target
# 8                             Data Scientist
# 9                             Data Scientist
#
#                                         job_location             company_name
# 0                 Noida, Nagpur, Bangalore/Bengaluru              GlobalLogic
# 1                     New Delhi, Bangalore/Bengaluru  Boston Consulting Group
# 2                                   Gurgaon/Gurugram               IHS Markit
# 3         Noida(Sector-59 Noida)\n(WFH during Covid)  R Systems International
# 4                                   Gurgaon/Gurugram                    Optum
# 5  New Delhi, Bangalore/Bengaluru, Mumbai (All Ar...             Big Seo Buzz
# 6  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...             Primo Hiring
# 7  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...           Okda Solutions
# 8                                              Noida             NGI Ventures
# 9  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...     torcai digital media

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#
# Brand
# Product Description
# Price The attributes which you have to scrape is ticked marked in the below image.
# To scrape the data you have to go through following steps:
#
# 1.Go to Flipkart webpage by url : https://www.flipkart.com/
# 2.Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# 3.After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data as usual
# 4.After scraping data from the first page, go to the “Next” Button at the bottom other page , then click on it.
# 5.Now scrape data from this page as usual
# 6.Repeat this until you get data for 100 sunglasses.

# %%
#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#Go to Flipkart webpage by url : https://www.flipkart.com/

driver.get("https://www.flipkart.com/")

# %%
popup= driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")

popup.click()

# %%
#Lets enter “sunglasses” in the search field where “search for products, brands and more” is written

des= driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

des.send_keys("Sunglasses")

# %%
# click the search icon

search= driver.find_element(By.CLASS_NAME, "_34RNph")
search.click()

# %%
#Scrap the required data 1. Brand, 2. Product Description, 3. Price, 4.Discount

brand_name=[]
product_description=[]
price=[]

# %%
# Scraping first 100 Brand from the given page

# Scraping data from the first page
start=1
end=4
for page in range(start, end):
    brand_tags= driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags:
        x= i.text
        brand_name.append(x)
    
    #Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') 
    next_button.click()
    time.sleep(8)
Top100_brand_name= brand_name[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Scraping first 100 Product Description from the given page

# Scraping data from the first page
start=1
end=4
for page in range(start, end):
    product_tags= driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_tags:
        x= i.text
        product_description.append(x)
    
    #Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
Top100_product_description= product_description[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Scraping first 100 Price from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        x= i.text
        price.append(x)
    
    #Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
Top100_price= price[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
#checking the length

print (len(Top100_brand_name), len(Top100_product_description), len(Top100_price))
# Out:
# 100 100 100

# %%
# Creating DataFrame to scrap first 10 data

data_list= list(zip(Top100_brand_name, Top100_product_description, Top100_price))

data= pd.DataFrame(data_list, 
    columns =['Brand_Name', 'Product Description', 'Price'],
    index=pd.RangeIndex(start=1, stop=101, name='Sr. No.'))

data = data.style.set_properties(**{'text-align': 'right'})

_col0, #T_24a79_row37_col1, #T_24a79_row37_col2, #T_24a79_row38_col0, #T_24a79_row38_col1, #T_24a79_row38_col2, #T_24a79_row39_col0, #T_24a79_row39_col1, #T_24a79_row39_col2, #T_24a79_row40_col0, #T_24a79_row40_col1, #T_24a79_row40_col2, #T_24a79_row41_col0, #T_24a79_row41_col1, #T_24a79_row41_col2, #T_24a79_row42_col0, #T_24a79_row42_col1, #T_24a79_row42_col2, #T_24a79_row43_col0, #T_24a79_row43_col1, #T_24a79_row43_col2, #T_24a79_row44_col0, #T_24a79_row44_col1, #T_24a79_row44_col2, #T_24a79_row45_col0, #T_24a79_row45_col1, #T_24a79_row45_col2, #T_24a79_row46_col0, #T_24a79_row46_col1, #T_24a79_row46_col2, #T_24a79_row47_col0, #T_24a79_row47_col1, #T_24a79_row47_col2, #T_24a79_row48_col0, #T_24a79_row48_col1, #T_24a79_row48_col2, #T_24a79_row49_col0, #T_24a79_row49_col1, #T_24a79_row49_col2, #T_24a79_row50_col0, #T_24a79_row50_col1, #T_24a79_row50_col2, #T_24a79_row51_col0, #T_24a79_row51_col1, #T_24a79_row51_col2, #T_24a79_row52_col0, #T_24a79_row52_col1, #T_24a79_row52_col2, #T_24a79_row53_col0, #T_24a79_row53_col1, #T_24a79_row53_col2, #T_24a79_row54_col0, #T_24a79_row54_col1, #T_24a79_row54_col2, #T_24a79_row55_col0, #T_24a79_row55_col1, #T_24a79_row55_col2, #T_24a79_row56_col0, #T_24a79_row56_col1, #T_24a79_row56_col2, #T_24a79_row57_col0, #T_24a79_row57_col1, #T_24a79_row57_col2, #T_24a79_row58_col0, #T_24a79_row58_col1, #T_24a79_row58_col2, #T_24a79_row59_col0, #T_24a79_row59_col1, #T_24a79_row59_col2, #T_24a79_row60_col0, #T_24a79_row60_col1, #T_24a79_row60_col2, #T_24a79_row61_col0, #T_24a79_row61_col1, #T_24a79_row61_col2, #T_24a79_row62_col0, #T_24a79_row62_col1, #T_24a79_row62_col2, #T_24a79_row63_col0, #T_24a79_row63_col1, #T_24a79_row63_col2 ...
#   text-align: right;
# }
# </style>
# <table id="T_24a79_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Brand_Name</th>
#       <th class="col_heading level0 col1" >Product Description</th>
#       <th class="col_heading level0 col2" >Price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sr. No.</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24a79_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_24a79_row0_col0" class="data row0 col0" >ROZZETTA CRAFT</td>
#       <td id="T_24a79_row0_col1" class="data row0 col1" >Mirrored, Night Vision, UV Protection, Riding Glasses S...</td>
#       <td id="T_24a79_row0_col2" class="data row0 col2" >₹279</td>
#     </tr>
#     <tr>
#       <th id="T_24a79_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_24a79_row1_col0" class="data row1 col0" >Singco India</td>
#       <td id="T_24a79_row1_col1" class="data row1 col1" >UV Protection, Mirrored Wayfarer Sunglasses (57)</td>
#       <td id="T_24a79_row1_col2" class="data row1 col2" >₹175</td>
#     </tr>
#     <tr>
#       <th id="T_24a79_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_24a79_row2_col0" class="data row2 col0" >Fastrack</td>
#       <td id="T_24a79_row2_col1" class="data row2 col1" >UV Protection Wayfarer Sunglasses (57)</td>
#       <td id="T_24a79_row2_col2" class="data row2 col2" >₹185</td>
#     </tr>
#     <tr>
#       <th id="T_24a79_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_24a79_row3_col0" class="data row3 col0" >S

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. This task will be done in following steps:
#
# First get the webpage https://www.flipkart.com/
# Enter “iphone 11” in “Search” field .
# Then click the search button. You will reach to the below shown webpage . As shown in the above page you have to scrape the tick marked attributes.These are:
# Rating
# Review summary
# Full review
# You have to scrape this data for first 100 reviews.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Lets first connect to the driver

#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#Go to Flipkart webpage by url : https://www.flipkart.com/

driver.get("https://www.flipkart.com/")

# %%
# close the popup window

popup_close = driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
popup_close.click()

# %%
# lets Enter “iphone 11” in “Search” field

des= driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
des.send_keys("iphone 11")

# %%
#click on search 

search= driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search.click()

# %%
#click the first results from all iphone 11 data

click_first = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[2]')
click_first.click()

# %%
# as the result open up in new tab of the browser we need to go that tab

driver.switch_to.window(driver.window_handles[1])

# %%
#clicking on the all reviews button

all_rev = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[7]/div/a/div/span')
all_rev.click()

# %%
#Scrap the required data Rating, Review summary, Full review

ratings=[]
review_summary=[]
full_review=[]

# %%
# Scraping first 100 Ratings the given page

start = 0 #starting page
end = 10 # page number to end scaping


for page in range(start,end):
    
    #scrape the ratings
    
    rating_tags = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tags:
        x= i.text
        ratings.append(x)
        
    #getting the nextpage button & clicking next 
    
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)

# %%
len(ratings)
# Out:
# 100

# %%
# Scraping first 100 Review summary the given page

start = 0 #starting page
end = 10 # page number to end scaping


for page in range(start,end):
    
    # scrape the review summaries
    
    review_sum_tags = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in review_sum_tags:
        x= i.text
        review_summary.append(x)    
    
    #getting the nextpage button & clicking next 
    
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)

# %%
len(review_summary)
# Out:
# 100

# %%
# Scraping first 100 full review the given page

start = 0 #starting page
end = 10 # page number to end scraping


for page in range(start,end):
    
    # scrape the full reviews
    
    full_review_tags = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full_review_tags:
        x= i.text
        full_review.append(x.replace("\n"," "))
        
    #getting the nextpage button & clicking next 
    
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)

# %%
len(full_review)
# Out:
# 110

# %%
# Creating DataFrame to scrap first 10 data

data_list= list(zip(ratings, review_summary, full_review))

data= pd.DataFrame(data_list,
    columns =['Ratings', 'Review Summary', 'Full Summary'],
    index=pd.RangeIndex(start=1, stop=101, name='Sr. No.'))

data = data.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("First 100 reviews data from flipkart.com for iphone11 phone:\n")
data
# Out:
# First 100 reviews data from flipkart.com for iphone11 phone:
# <style type="text/css">
6ddf7_row38_col0, #T_6ddf7_row38_col1, #T_6ddf7_row38_col2, #T_6ddf7_row39_col0, #T_6ddf7_row39_col1, #T_6ddf7_row39_col2, #T_6ddf7_row40_col0, #T_6ddf7_row40_col1, #T_6ddf7_row40_col2, #T_6ddf7_row41_col0, #T_6ddf7_row41_col1, #T_6ddf7_row41_col2, #T_6ddf7_row42_col0, #T_6ddf7_row42_col1, #T_6ddf7_row42_col2, #T_6ddf7_row43_col0, #T_6ddf7_row43_col1, #T_6ddf7_row43_col2, #T_6ddf7_row44_col0, #T_6ddf7_row44_col1, #T_6ddf7_row44_col2, #T_6ddf7_row45_col0, #T_6ddf7_row45_col1, #T_6ddf7_row45_col2, #T_6ddf7_row46_col0, #T_6ddf7_row46_col1, #T_6ddf7_row46_col2, #T_6ddf7_row47_col0, #T_6ddf7_row47_col1, #T_6ddf7_row47_col2, #T_6ddf7_row48_col0, #T_6ddf7_row48_col1, #T_6ddf7_row48_col2, #T_6ddf7_row49_col0, #T_6ddf7_row49_col1, #T_6ddf7_row49_col2, #T_6ddf7_row50_col0, #T_6ddf7_row50_col1, #T_6ddf7_row50_col2, #T_6ddf7_row51_col0, #T_6ddf7_row51_col1, #T_6ddf7_row51_col2, #T_6ddf7_row52_col0, #T_6ddf7_row52_col1, #T_6ddf7_row52_col2, #T_6ddf7_row53_col0, #T_6ddf7_row53_col1, #T_6ddf7_row53_col2, #T_6ddf7_row54_col0, #T_6ddf7_row54_col1, #T_6ddf7_row54_col2, #T_6ddf7_row55_col0, #T_6ddf7_row55_col1, #T_6ddf7_row55_col2, #T_6ddf7_row56_col0, #T_6ddf7_row56_col1, #T_6ddf7_row56_col2, #T_6ddf7_row57_col0, #T_6ddf7_row57_col1, #T_6ddf7_row57_col2, #T_6ddf7_row58_col0, #T_6ddf7_row58_col1, #T_6ddf7_row58_col2, #T_6ddf7_row59_col0, #T_6ddf7_row59_col1, #T_6ddf7_row59_col2, #T_6ddf7_row60_col0, #T_6ddf7_row60_col1, #T_6ddf7_row60_col2, #T_6ddf7_row61_col0, #T_6ddf7_row61_col1, #T_6ddf7_row61_col2, #T_6ddf7_row62_col0, #T_6ddf7_row62_col1, #T_6ddf7_row62_col2, #T_6ddf7_row63_col0, #T_6ddf7_row63_col1, #T_6ddf7_row63_col2 ...
#   text-align: right;
# }
# </style>
# <table id="T_6ddf7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Ratings</th>
#       <th class="col_heading level0 col1" >Review Summary</th>
#       <th class="col_heading level0 col2" >Full Summary</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sr. No.</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ddf7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6ddf7_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_6ddf7_row0_col1" class="data row0 col1" >Value-for-money</td>
#       <td id="T_6ddf7_row0_col2" class="data row0 col2" >It's my first time to use iOS phone and I am loving my upgradation 😍😍 I love the color, I love the assebility of the phone....I need to learn more about its functionality, but as far as I have seen, it's quite easy and it has a lot of functions to work on, specially if you are a content writer or a blogger you get a lot of content creation platforms and they are really amazing.  This phone not only for good quality photography but a lot of other task too.😍💯</td>
#     </tr>
#     <tr>
#       <th id="T_6ddf7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6ddf7_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_6ddf7_row1_col1" class="data row1 col1" >Simply awesome</td>
#       <td id="T_6ddf7_row1_col2" class="data row1 col2" >It is just awesome mobile for this price from Apple,  After 10 days review  Battery enough for 1 day even 24*7 Internet will be on and mostl

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field. You have to scrape 4 attributes of each sneaker:
#
# Brand
# Product Description
# Price As shown in the below image, you have to scrape the tick marked attributes

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Lets first connect to the driver

#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#Go to Flipkart webpage by url : https://www.flipkart.com/

driver.get("https://www.flipkart.com/")

# %%
# close the popup window

popup= driver.find_element(By.XPATH, "/html/body/div[2]/div/div/button")
popup.click()

# %%
# lets Enter “iphone 11” in “Search” field

des= driver.find_element(By.XPATH, "/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

des.send_keys("sneakers")

# %%
des.send_keys("sneakers")

#click on search button

search= driver.find_element(By.CLASS_NAME, "L0Z3Pu")
search.click()

# %%
#Scrap the required data Brand, Product Description, Price, Discount (as shown in the given picture)

brand_name=[]
product_description=[]
price=[]
discount=[]

# %%
# Scraping first 100 Brand from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    brand_tags= driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags:
        x= i.text
        brand_name.append(x)
    
    # Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)
Top100_brand_name= brand_name[0:100] #Top 100 data

# %%
len(brand_name)
# Out:
# 120

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Scraping first 100 Product Description from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    product_tags= driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_tags:
        x= i.text
        product_description.append(x)
        
    
    # Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
Top100_product_description= product_description[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Scraping first 100 Price from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        x= i.text
        price.append(x)
        
    # Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') #Go to the “Next” Button at the bottom other page and scrap data
    next_button.click()
    time.sleep(3)
Top100_price= price[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Scraping first 100 Discount from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in price_tags:
        x= i.text
        discount.append(x) 
        
    # Go to the “Next” Button at the bottom other page and scrap data
     
    next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]') #Go to the “Next” Button at the bottom other page and scrap data
    next_button.click()
    time.sleep(3)
Top100_discount = discount[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
prev_button.click()

# %%
# Creating DataFrame of first 100 scrapped data

list_data= list(zip(Top100_brand_name, Top100_product_description, Top100_price, Top100_discount))

data= pd.DataFrame( list_data,
        index=pd.RangeIndex(start=1, stop=101, name='Sr. No.'),
        columns =['Brand_Name','Product Description', 'Price', 'Discount'])

data = data.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("First 100 sneakers data from Flipkart is:\n")
data
# Out:
# First 100 sneakers data from Flipkart is:
# <style type="text/css">
089_row33_col2, #T_28089_row33_col3, #T_28089_row34_col0, #T_28089_row34_col1, #T_28089_row34_col2, #T_28089_row34_col3, #T_28089_row35_col0, #T_28089_row35_col1, #T_28089_row35_col2, #T_28089_row35_col3, #T_28089_row36_col0, #T_28089_row36_col1, #T_28089_row36_col2, #T_28089_row36_col3, #T_28089_row37_col0, #T_28089_row37_col1, #T_28089_row37_col2, #T_28089_row37_col3, #T_28089_row38_col0, #T_28089_row38_col1, #T_28089_row38_col2, #T_28089_row38_col3, #T_28089_row39_col0, #T_28089_row39_col1, #T_28089_row39_col2, #T_28089_row39_col3, #T_28089_row40_col0, #T_28089_row40_col1, #T_28089_row40_col2, #T_28089_row40_col3, #T_28089_row41_col0, #T_28089_row41_col1, #T_28089_row41_col2, #T_28089_row41_col3, #T_28089_row42_col0, #T_28089_row42_col1, #T_28089_row42_col2, #T_28089_row42_col3, #T_28089_row43_col0, #T_28089_row43_col1, #T_28089_row43_col2, #T_28089_row43_col3, #T_28089_row44_col0, #T_28089_row44_col1, #T_28089_row44_col2, #T_28089_row44_col3, #T_28089_row45_col0, #T_28089_row45_col1, #T_28089_row45_col2, #T_28089_row45_col3, #T_28089_row46_col0, #T_28089_row46_col1, #T_28089_row46_col2, #T_28089_row46_col3, #T_28089_row47_col0, #T_28089_row47_col1, #T_28089_row47_col2, #T_28089_row47_col3, #T_28089 ...

# %% [markdown]
# Q7: Go to the link - https://www.myntra.com/shoes Set second Price filter and Color filter to “Black”, as shown in the below image.
#
# And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe description, price of the shoe as shown in the below image.

# %%
#Lets first connect to the driver

#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#Go to Flipkart webpage by url: https://www.myntra.com/shoes

driver.get(" https://www.myntra.com/shoes")

# %%
#apply second price filter 

price_filter = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label')
price_filter.click()

# %%
#apply Color filter to “Black”

color_filter = driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label')
color_filter.click()

# %%
#Scrap the required data Brand, Product Description, Price

brand_name=[]
product_description=[]
price=[]

# %%
# Scraping first 100 Brand from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    brand_tags= driver.find_elements(By.XPATH,'//h3[@class="product-brand"]')
    for i in brand_tags:
        x= i.text
        brand_name.append(x)
        
    # Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//li[@class="pagination-next"]') #Go to the “Next” Button at the bottom other page and scrap data
    next_button.click()
    time.sleep(3)
Top100_brand_name= brand_name[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[3]/a')
prev_button.click()

# %%
# Scraping first 100 Product Description from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    product_tags= driver.find_elements(By.XPATH,'//h4[@class="product-product"]')
    for i in product_tags:
        x= i.text
        product_description.append(x)
        
    # Go to the “Next” Button at the bottom other page and scrap data
        
    next_button= driver.find_element(By.XPATH,'//li[@class="pagination-next"]')
    next_button.click()
    time.sleep(3)
Top100_product_description= product_description[0:100] #Top 100 data

# %%
# Bring to 1st page

prev_button= driver.find_element(By.XPATH,'/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[3]/a')
prev_button.click()

# %%
# Scraping first 100 Price from the given page

# Scraping data from the first page
start=0
end=3
for page in range(start, end):
    price_tags= driver.find_elements(By.XPATH,'//div[@class="product-price"]')
    for i in price_tags:
        x= i.text
        price.append(x)
        
    # Go to the “Next” Button at the bottom other page and scrap data
    
    next_button= driver.find_element(By.XPATH,'//li[@class="pagination-next"]') #Go to the “Next” Button at the bottom other page and scrap data
    next_button.click()
    time.sleep(3)
Top100_price= price[0:100] #Top 100 data

# %%
print(len(Top100_brand_name), len(Top100_product_description), len(Top100_price))
# Out:
# 100 100 100

# %%
# Creating DataFrame of first 100 scrapped data

list_data= list(zip(Top100_brand_name, Top100_product_description, Top100_price))

data= pd.DataFrame( list_data,
        index=pd.RangeIndex(start=1, stop=101, name='Sr. No.'),
        columns =['Brand_Name','Product Description', 'Price'])

data = data.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("First 100 sneakers data from Flipkart is:\n")
data
# Out:
# First 100 sneakers data from Flipkart is:
# <style type="text/css">
# #T_8f0c7_row0_col0, #T_8f0c7_row0_col1, #T_8f0c7_row0_col2, #T_8f0c7_row1_col0, #T_8f0c7_row1_col1, #T_8f0c7_row1_col2, #T_8f0c7_row2_col0, #T_8f0c7_row2_col1, #T_8f0c7_row2_col2, #T_8f0c7_row3_col0, #T_8f0c7_row3_col1, #T_8f0c7_row3_col2, #T_8f0c7_row4_col0, #T_8f0c7_row4_col1, #T_8f0c7_row4_col2, #T_8f0c7_row5_col0, #T_8f0c7_row5_col1, #T_8f0c7_row5_col2, #T_8f0c7_row6_col0, #T_8f0c7_row6_col1, #T_8f0c7_row6_col2, #T_8f0c7_row7_col0, #T_8f0c7_row7_col1, #T_8f0c7_row7_col2, #T_8f0c7_row8_col0, #T_8f0c7_row8_col1, #T_8f0c7_row8_col2, #T_8f0c7_row9_col0, #T_8f0c7_row9_col1, #T_8f0c7_row9_col2, #T_8f0c7_row10_col0, #T_8f0c7_row10_col1, #T_8f0c7_row10_col2, #T_8f0c7_row11_col0, #T_8f0c7_row11_col1, #T_8f0c7_row11_col2, #T_8f0c7_row12_col0, #T_8f0c7_row12_col1, #T_8f0c7_row12_col2, #T_8f0c7_row13_col0, #T_8f0c7_row13_col1, #T_8f0c7_row13_col2, #T_8f0c7_row14_col0, #T_8f0c7_row14_col1, #T_8f0c7_row14_col2, #T_8f0c7_row15_col0, #T_8f0c7_row15_col1, #T_8f0c7_row15_col2, #T_8f0c7_row16_col0, #T_8f0c7_row16_col1, #T_8f0c7_row16_col2, #T_8f0c7_row17_col0, #T_8f0c7_row17_col1, #T_8f0c7_row17_col2, #T_8f0c7_row18_col0, #T_8f0c7_row18_col1, #T_8f0c7_row18_col2, #T_8f0c7_row19_col0, #T_8f0c7_row19_col1, #T_8f0c7_row19_col2, #T_8f0c7_row20_col0, #T_8f0c7_row20_col1, #T_8f0c7_row20_col2, #T_8f0c7_row21_col0, #T_8f0c7_row21_col1, #T_8f0c7_row21_col2, #T_8f0c7_row22_col0, #T_8f0c7_
_col1, #T_8f0c7_row56_col2, #T_8f0c7_row57_col0, #T_8f0c7_row57_col1, #T_8f0c7_row57_col2, #T_8f0c7_row58_col0, #T_8f0c7_row58_col1, #T_8f0c7_row58_col2, #T_8f0c7_row59_col0, #T_8f0c7_row59_col1, #T_8f0c7_row59_col2, #T_8f0c7_row60_col0, #T_8f0c7_row60_col1, #T_8f0c7_row60_col2, #T_8f0c7_row61_col0, #T_8f0c7_row61_col1, #T_8f0c7_row61_col2, #T_8f0c7_row62_col0, #T_8f0c7_row62_col1, #T_8f0c7_row62_col2, #T_8f0c7_row63_col0, #T_8f0c7_row63_col1, #T_8f0c7_row63_col2 ...
#   text-align: right;
# }
# </style>
# <table id="T_8f0c7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Brand_Name</th>
#       <th class="col_heading level0 col1" >Product Description</th>
#       <th class="col_heading level0 col2" >Price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sr. No.</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f0c7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8f0c7_row0_col0" class="data row0 col0" >Skechers</td>
#       <td id="T_8f0c7_row0_col1" class="data row0 col1" >Men GO WALK - TERRA Shoes</td>
#       <td id="T_8f0c7_row0_col2" class="data row0 col2" >Rs. 8499Rs. 9999(15% OFF)</td>
#     </tr>
#     <tr>
#       <th id="T_8f0c7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8f0c7_row1_col0" class="data row1 col0" >ADIDAS</td>
#       <td id="T_8f0c7_row1_col1" class="data row1 col1" ></td>
#       <td id="T_8f0c7_row1_col2" class="data row1 col2" >Rs. 11199Rs. 15999(30% OFF)</td>
#     </tr>
#     <tr>
#       <th id="T_8f0c7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8f0c7_row2_col0" class="data row2 col0" >Skechers</td>
#       <td id="T_8f0c7_row2_col1" class="data row2 col1" >Men Go Run Hyper Burst Running</td>
#       <td id="T_8f0c7_row2_col2" class="data row2 col2" >Rs. 7224Rs. 8499(15% OFF)</td>
#     </tr>
#     <tr>
#       <th id="T_8f0c7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8f0c7_row3_col0" class="data row3 col0" >ADIDAS Originals</td>
#       <td id="T

# %% [markdown]
# #Q8: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7”

# %%
#Lets first connect to the driver

#First connect to the driver

driver= webdriver.Chrome(r"C:\Users\sahal\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %%
#Go to Flipkart webpage by url: https://www.amazon.in/

driver.get("https://www.amazon.in/")

# %%
# Lets enter Laptop in the search field and then click the search icon.

des= driver.find_element(By.XPATH, "/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
des.send_keys("Laptop")

# %%
# click the search button

search= driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
# select cpu filter

cpu_filter_i7 = driver.find_element(By.XPATH,'//li[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span/a/span')
cpu_filter_i7.click()

# %%
#Scrap the required data

title=[]
ratings=[]
price=[]

# %%
#title of the laptops

#title_tags= driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
title_tags = driver.find_elements(By.XPATH,"//span[@class='a-size-medium a-color-base a-text-normal']")
for i in title_tags[0:10]:
    x= i.text
    title.append(x)
title
# Out:
# ['ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FHD OLED, Intel EVO Core i7-1165G7 11th Gen, Thin and Light Laptop (16GB/1TB SSD/Iris Xe Graphics/Windows 11/Office 2021/Mist/1.14 kg), UX325EA-KG701WS',
#  'ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, Intel Core i7-1065G7 10th Gen, Thin and Light Laptop (16GB/512GB SSD/Iris Plus Graphics/Windows 11/Office 2021/Silver/1.8 kg), X515JA-EJ701WS',
#  'Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN',
#  'Lenovo ThinkBook 15 Intel 11th Gen Core i7 15.6"(39.62 cm)FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11 Home/MS Office H&S 2021/Iris® Xe Graphics/Backlit/Mineral Grey/1.7 Kg) 20VE00W4IH',
#  'HP Pavilion Plus, 12th Gen Intel Core i7 16GB RAM/1TB SSD 14 inch(35.6 cm),OLED,400 nits,UWVA, Eye Safe Laptop/Intel Iris Xe Graphics/Backlit KB/B&O/FPR/Win 11/Alexa Built-in/MSO 2021, 14-eh0024TU',
#  'HP Pavilion x360 11th Gen Intel Core i7 14 inch(35.6 cm) FHD,IPS, Multitouch 2-in-1 Laptop(16GB RAM/512GB SSD/Backlit KB/Intel Iris Xe Graphics/Pen/Alexa Built-in/MSO/1.52Kg) 14-dy1050TU, Spruce Blue',
#  'Lenovo Yoga 7i 11th Gen Intel Core i7-1165G7 14 inches FHD IPS 2-in-1 Touchscreen Business Laptop (16GB/512GB SSD/Windows 10/MS Office/Digital Pen/Fingerprint Reader/Slate Grey/1.43Kg), 82BH004HIN',
#  'Lenovo IdeaPad Gaming 3 Intel Core i7-12700H 16"(40.64cm) WUXGA IPS 165Hz Gaming Laptop (16GB/512GB SSD/Win 11/Office 2021/NVIDIA RTX 3060 6GB/Alexa/3 Month Game Pass/Onyx Grey/2.6Kg),82SA00B2IN',
#  'ASUS TUF Gaming F15 (2022), 15.6" (39.62 cms) FHD 144Hz, Intel Core i7-12700H 12th Gen, RTX 3050 Ti 4GB Graphics, Gaming Laptop (16GB/512GB SSD/Windows 11/Gray/2.2 kg), FX577ZE-HN056W',
#  '(Renewed) Lenovo Intel Core i7 5600U 12.5-Inch (31.75 cms) HD (1366 X 768) Laptop (8 GB/256 GB SSD/Windows 10/Intel HD 5500//1.53 Kg), Lenovo X250']

# %%
#ratings 
rating_tags=driver.find_elements(By.XPATH,"//a[@class='a-popover-trigger a-declarative']")

for i in rating_tags[0:10]:
    if i.text is None:
        ratings.append("--")
    else:
        ratings.append(i.get_attribute("text"))

# %%
#prices of the laptops

price_tags=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in price_tags[0:10]:
    x= i.text
    price.append(x)

# %%
# Creating DataFrame of first 10 scrapped data

list_data= list(zip(title, ratings, price))

data= pd.DataFrame( list_data,
        index=pd.RangeIndex(start=1, stop=11, name='Sr. No.'),
        columns =['Title_of_Laptop', 'Ratings', 'Price'])

data = data.style.set_properties(**{'text-align': 'right'})

#Print the required data

print ("First 10 laptop's data from Amazon is:\n\n")
data
# Out:
# First 10 laptop's data from Amazon is:
# <style type="text/css">
# #T_4de68_row0_col0, #T_4de68_row0_col1, #T_4de68_row0_col2, #T_4de68_row1_col0, #T_4de68_row1_col1, #T_4de68_row1_col2, #T_4de68_row2_col0, #T_4de68_row2_col1, #T_4de68_row2_col2, #T_4de68_row3_col0, #T_4de68_row3_col1, #T_4de68_row3_col2, #T_4de68_row4_col0, #T_4de68_row4_col1, #T_4de68_row4_col2, #T_4de68_row5_col0, #T_4de68_row5_col1, #T_4de68_row5_col2, #T_4de68_row6_col0, #T_4de68_row6_col1, #T_4de68_row6_col2, #T_4de68_row7_col0, #T_4de68_row7_col1, #T_4de68_row7_col2, #T_4de68_row8_col0, #T_4de68_row8_col1, #T_4de68_row8_col2, #T_4de68_row9_col0, #T_4de68_row9_col1, #T_4de68_row9_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_4de68_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Title_of_Laptop</th>
#       <th class="col_heading level0 col1" >Ratings</th>
#       <th class="col_heading level0 col2" >Price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sr. No.</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4de68_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4de68_row0_col0" class="data row0 col0" >ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FHD OLED, Intel EVO Core i7-1165G7 11th Gen, Thin and Light Laptop (16GB/1TB SSD/Iris Xe Graphics/Windows 11/Office 2021/Mist/1.14 kg), UX325EA-KG701WS</td>
#       <td id="T_4de68_row0_col1" class="data row0 col1" >4.2 out of 5 stars</td>
#       <td id="T_4de68_row0_col2" class="data row0 col2" >93,290</td>
#     </tr>
#     <tr>
#       <th id="T_4de68_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4de68_row1_col0" class="data row1 col0" >ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, Intel Core i7-1065G7 10th Gen, Thin and Light Laptop (16GB/512GB SSD/Iris Plus Graphics/Windows 11/Office 2021/Silver/1.8 kg), X515JA-EJ701WS</td>
#       <td id="T_4de68_row1_col1" class="data row1 col1" >3.7 out of 5 stars</td>
#       <td id="T_4de68_row1_col2" class="data row1 col2" >64,990</td>
#     </tr>
#     <tr>
#       <th id="T_4de68_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4de68_row2_col0" class="data row2 col0" >Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN</td>
#       <td id="T_4de68_row2_col1" class="data row2 col1" >4.4 out of 5 stars</td>
#       <td id="T_4de68_row2_col2" class="data row2 col2" >79,990</td>
#     </tr>
#     <tr>
#       <th id="T_4de68_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4de68_row3_col0" class="data row3 col0" >Lenovo ThinkBook 15 Intel 11th Gen Core i7 15.6"(39.62 cm)FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11 Home/MS Office H&S 2021/Iris® Xe Graphics/Backlit/Mineral Grey/1.7 Kg) 20VE00W4IH</td>
#       <td id="T_4de68_row3_col1" class="data row3 col1" >4.3 out of 5 stars</td>
#       <td id="T_4de68_row3_col2" class="data row3 col2" >77,990</td>
#     </tr>
#     <tr>
#       <th id="T_4de68_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_4de68_row4_col0" class="data row4 col0" >HP Pavilion Plus, 12th Gen Intel Core i7 16GB RAM/1TB SSD 14 inch(35.6 cm),OLED,400 nits,UWVA, Eye Safe Laptop/Intel Iris Xe Graphics/Backlit KB/B&O/FPR/Win 11/Alexa Built-in/MSO 2021, 14-eh0024TU</td>
#       <td id="T_4de68_row4_col1" class="data row4 col1" >4.2 out of 5 stars</td>
#       <td id="T_4de68_row4_col2" class="data row4 col2" >86,990</td>
#     </tr>
#     <tr>
#       <th id="T_4de68_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_4de68_row5_col0" class="data row5 col0" >HP Pavilion x360 11th Gen Intel Core i7 14 inch(35.6 cm) FHD,IPS, Multitouch 2-in-1 Laptop(16GB RAM/512GB SSD/Backlit KB/Intel Iris Xe Graphics/Pen/Alexa Built-in/MSO/1.52Kg) 14-dy1050TU, Spruce Blue</td>
#       <td id="T_4de68_row5_col1" class="data row5 col1" >4.2 out of 5 stars</td>
#       <td id="T_4de68_row5_col2" class="data row5 col2" >80,990</td>
#     </tr>
#     <tr>
#       <th id="T_4de68_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_4de68_row6_col0" class="data row6 col0" >Lenovo Yoga 7i 11th Gen Intel Core i7-1165G7 14 inches FHD IPS 2-in-1 Touchscreen Business Laptop (16GB/512GB SSD/Windows 10/MS Office/Digital Pen/Fingerprint Reader/Slate Grey/1.43Kg), 82BH004HIN</td>
#       <td id="T_4de68_row6_col1" class="data row6 col1" >4.4 out of 5 stars</td>
#       <td id="T_4de68_row6_col2" class="data row6 col2" >1,11,000</td>
#     </tr>
#     <tr>
#       <th id="T_4de68_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_4de68_row7_col0" class="data row7 col0" >Lenovo IdeaPad Gaming 3 Intel Core i7-12700H 16"(40.64cm) WUXGA IPS 165Hz Gaming Laptop (16GB/512GB SSD/Win 11/Office 2021/NVIDIA RTX 3060 6GB/Alexa/3 Month Game Pass/Onyx Grey/2.6Kg),82SA00B2IN</td>
#       <td id="T_4de68_row7_col1" class="data row7 col1" >4.2 out of 5 stars</td>
#       <td id="T_4de68_row7_col2" class="data row7 col2" >1,09,990</td>
#     </tr>
#     <tr>
#       <th id="T_4de68_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_4de68_row8_col0" class="data row8 col0" >ASUS TUF Gaming F15 (2022), 15.6" (39.62 cms) FHD 144Hz, Intel Core i7-12700H 12th Gen, RTX 3050 Ti 4GB Graphics, Gaming Laptop (16GB/512GB SSD/Windows 11/Gray/2.2 kg), FX577ZE-HN056W</td>
#       <td id="T_4de68_row8_col1" class="data row8 col1" >2.9 out of 5 stars</td>
#       <td id="T_4de68_row8_col2" class="data row8 col2" >99,990</td>
#     </tr>
#     <tr>
#       <th id="T_4de68_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_4de68_row9_col0" class="data row9 col0" >(Renewed) Lenovo Intel Core i7 5600U 12.5-Inch (31.75 cms) HD (1366 X 768) Laptop (8 GB/256 GB SSD/Windows 10/Intel HD 5500//1.53 Kg), Lenovo X250</td>
#       <td id="T_4de68_row9_col1" class="data row9 col1" >3.6 out of 5 stars</td>
#       <td id="T_4de68_row9_col2" class="data row9 col2" >21,999</td>
#     </tr>
#   </tbody>
# </table>
